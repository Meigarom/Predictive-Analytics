# %% [markdown]
# # 0.0 IMPORTS
# ---

# %%
import json
import pickle
import pandas                                                 as pd
import seaborn                                                as sns
import xgboost                                                
import warnings                               
import requests 

from time                      import time
from boruta                    import BorutaPy
from datetime                  import datetime, timedelta
from matplotlib                import pyplot                  as plt
from IPython.core.display      import HTML

from sklearn.svm               import SVR
from sklearn.metrics           import mean_absolute_error, mean_squared_error
from sklearn.ensemble          import RandomForestRegressor
from sklearn.linear_model      import LinearRegression, Lasso, LassoCV
from sklearn.preprocessing     import LabelEncoder, MinMaxScaler
from sklearn.model_selection   import train_test_split, KFold, RandomizedSearchCV, GridSearchCV
from sklearn.feature_selection import RFECV

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 0.1. Helper Functions

# %%
# --- Jupyter Notebook Settings
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25,12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>' ) )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()
    
    
def save_parameter_encoder( encoder, param_name, label ):
    if label == 'label_encoder':
        keys = encoder.classes_
        values = encoder.transform( encoder.classes_ )
        param = dict( zip( keys, values ) )
        
    else: #label == 'minmax'
        param = {'min': mms.data_min_, 'max': mms.data_max_}
    
    pickle.dump( param, open( '/Users/meigarom/repos/Predictive-Analytics/parameter/param_{}.pkl'.format( param_name ), 'wb' ) )
    
    
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean( ( np.abs( y_true - y_pred ) / y_true ) )


def mean_percentage_error(y_true, y_pred): 
    return np.mean( ( y_true - y_pred ) / y_true )
    
    
def rmspe( y, yhat ):
    return np.sqrt( np.mean( ( yhat/y-1) **2 ) )


def rmspe_xg( yhat, y ):
    y = np.expm1( y.get_label() )
    yhat = np.expm1( yhat )
    return 'rmspe', rmspe( y, yhat )


def ml_error( model_name, y_test, yhat ):
    error = rmspe( y_test, yhat )
    mae = mean_absolute_error( y_test, yhat )
    mape = mean_absolute_percentage_error( y_test, yhat )
    rmse = np.sqrt( mean_squared_error( y_test, yhat ) )
    
    return pd.DataFrame( {'Model': model_name, 'MAE': mae, 'MAPE': mape, 'RMSE': rmse, 'RMSPE': error}, index=[0] )


def xgb_model( x_train, y_train, x_valid, y_valid, params ):
    dtrain = xgb.DMatrix( x_train, y_train )
    dvalid = xgb.DMatrix( x_valid, y_valid )
    watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
    return xgb.train( params, dtrain, num_boost_round=6000, evals=watchlist, early_stopping_rounds=100, feval=rmspe_xg, verbose_eval=False )


def nested_cross_validation( training_start, training_end, holdout_end, kfold, X_train, model, verbose=0 ):
    # result list
    mae_list = []
    mape_list = []
    rmse_list = []
    rmspe_list = []
    
    # how many days between training end and holdout end
    n_day = np.round( ( holdout_end - training_end ).days / kfold )
    
    # K fold cross validation
    for i in range( 1, kfold + 1 ):
        if verbose == 1:
            print( 'Fold K: {}'.format( i ) )
        # trainn
        fold_training_start = training_start
        fold_training_end = training_end + timedelta( days=( i - 1 )*n_day )
        
        # valid
        fold_valid_start = fold_training_end
        fold_valid_end = training_end + timedelta( days=( i * n_day ) )
        
        # model training with k fold
        x_train = X_train[(X_train['date'] >= fold_training_start) & (X_train['date'] <= fold_training_end)]
        y_train = x_train['sales']
        x_train = x_train.drop( ['sales', 'date'], axis=1 )

        # valid fold k
        x_valid = X_train[(X_train['date'] > fold_valid_start) & (X_train['date'] <= fold_valid_end)]
        y_valid = x_valid['sales']
        x_valid = x_valid.drop( ['sales', 'date'], axis=1 )
        
        # modelling
        model_fitted = model.fit( x_train, y_train )
        
        # predictions
        yhat = model_fitted.predict( x_valid )
        
        # performance
        results = ml_error( 'model', np.expm1( y_valid ), np.expm1( yhat ) )
        
        mae_list.append( results['MAE'][0] )
        mape_list.append( results['MAPE'][0] )
        rmse_list.append( results['RMSE'][0] )
        rmspe_list.append( results['RMSPE'][0] )
    
        #print( lr_results )
        #print( '\n')
    
    return { 'AVG MAE': np.mean( mae_list ), 'STD MAE': np.std( mae_list ), 
             'AVG MAPE': np.mean( mape_list ), 'STD MAPE': np.std( mape_list ), 
             'AVG RMSE': np.mean( rmse_list ), 'STD RMSE': np.std( rmse_list ), 
             'AVG RMSPE': np.mean( rmspe_list ), 'STD RMSPE': np.std( rmspe_list )}

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.2. Loading Data

# %%
df_sales_raw = pd.read_csv( '../data/train.csv' )
df_stores_raw = pd.read_csv( '../data/store.csv' )

# Merge dataset
df_raw = pd.merge( df_sales_raw, df_stores_raw, on='Store', how='left' )

# %% [markdown]
# # 1.0. DATA PREPARATION
# ---

# %%
df_raw.sample(2)
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 814794    515          1  2013-07-01  10256        803     1      1            0              0         d          c              11260.0                        NaN                       NaN       1              9.0           2011.0  Feb,May,Aug,Nov
# 129533    194          1  2015-04-06      0          0     0      0            b              1         d          c              16970.0                        NaN                       NaN       1              5.0           2013.0  Feb,May,Aug,Nov

# %% [markdown]
# ## 1.1. Rename Attributes

# %%
df1 = df_raw.copy()

# %%
# new columns name
new_cols=['store', 'day_of_week', 'date', 'sales', 'customers', 'open', 'promo', 'state_holiday', 'school_holiday', 'store_type', 'assortment', 'competition_distance', 'competition_open_since_month', 
          'competition_open_since_year', 'promo2', 'promo2_since_week', 'promo2_since_year', 'promo_interval']

# rename
df1.columns = new_cols

# %%
df1.sample(2)
# Out:
#         store  day_of_week        date  sales  customers  open  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year   promo_interval
# 748605    111            4  2013-08-29   7195        668     1      1             0               0          d          c                7890.0                           NaN                          NaN       1               37.0             2009.0  Jan,Apr,Jul,Oct
# 38516     607            6  2015-06-27   1084        136     1      0             0               0          a          a                 350.0                           8.0                       1999.0       1               14.0             2011.0  Jan,Apr,Jul,Oct

# %% [markdown]
# # 2.0. DESCRIBE DATA
# ---

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1. Data Dimensions

# %%
print( 'Number of Rows: {}'.format( df2.shape[0] ) )
print( 'Number of Columns: {}'.format( df2.shape[1] ) )
# Out:
# Number of Rows: 1017209
# Number of Columns: 18

# %% [markdown]
# ## 2.2. Data Type Attributes

# %%
df2.dtypes
# Out:
# store                             int64
# day_of_week                       int64
# date                             object
# sales                             int64
# customers                         int64
# open                              int64
# promo                             int64
# state_holiday                    object
# school_holiday                    int64
# store_type                       object
# assortment                       object
# competition_distance            float64
# competition_open_since_month    float64
# competition_open_since_year     float64
# promo2                            int64
# promo2_since_week               float64
# promo2_since_year               float64
# promo_interval                   object
# dtype: object

# %%
# convert to datetime
df2['date'] = pd.to_datetime( df2['date'] )

df2.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## 2.3. Number of NA

# %%
df2.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
# store                           1017209 non-null int64
# day_of_week                     1017209 non-null int64
# date                            1017209 non-null datetime64[ns]
# sales                           1017209 non-null int64
# customers                       1017209 non-null int64
# open                            1017209 non-null int64
# promo                           1017209 non-null int64
# state_holiday                   1017209 non-null object
# school_holiday                  1017209 non-null int64
# store_type                      1017209 non-null object
# assortment                      1017209 non-null object
# competition_distance            1014567 non-null float64
# competition_open_since_month    693861 non-null float64
# competition_open_since_year     693861 non-null float64
# promo2                          1017209 non-null int64
# promo2_since_week               509178 non-null float64
# promo2_since_year               509178 non-null float64
# promo_interval                  509178 non-null object
# dtypes: datetime64[ns](1), float64(5), int64(8), object(4)
# memory usage: 147.5+ MB

# %% [markdown]
# ## 2.4. Treat NA columns

# %%
df2.sample( 2 )
# Out:
#         store  day_of_week       date  sales  customers  open  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year promo_interval
# 21541     357            7 2015-07-12      0          0     0      0             0               0          a          a                2060.0                          10.0                       2008.0       0                NaN                NaN            NaN
# 761555    796            7 2013-08-18      0          0     0      0             0               0          a          c                7180.0                          11.0                       2012.0       0                NaN                NaN            NaN

# %%
# promo2_since_year
df2['promo2_since_year'] = df2.apply( lambda x: x['date'].year if math.isnan( x['promo2_since_year'] ) else x['promo2_since_year'], axis=1 )

# promo2_since_week
df2['promo2_since_week'] = df2.apply( lambda x: x['date'].weekofyear if math.isnan( x['promo2_since_week'] ) else x['promo2_since_week'], axis=1 )

# competition_distance
df2['competition_distance'] = df2['competition_distance'].apply( lambda x: 200000.0 if math.isnan( x ) else x )

# competition_open_since_month
df2['competition_open_since_month'] = df2.apply( lambda x: x['date'].month if math.isnan( x['competition_open_since_month'] ) else x['competition_open_since_month'], axis=1 ) 

# competition_open_since_year
df2['competition_open_since_year'] = df2.apply( lambda x: x['date'].year if math.isnan( x['competition_open_since_year'] ) else x['competition_open_since_year'], axis=1 )

# promo_interval
## fill na with 0
df2.fillna( 0, inplace=True )
# if date is in the promo interval, there is promo.
monthmap = {1:'Jan', 2:'Fev', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', 7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}
df2['month_map'] = df2['date'].dt.month.map( monthmap )
df2['is_promo'] = df2[['promo_interval', 'month_map']].apply( lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split( ',' ) else 0, axis=1 )

# %%
df2.isna().sum()
# Out:
# store                           0
# day_of_week                     0
# date                            0
# sales                           0
# customers                       0
# open                            0
# promo                           0
# state_holiday                   0
# school_holiday                  0
# store_type                      0
# assortment                      0
# competition_distance            0
# competition_open_since_month    0
# competition_open_since_year     0
# promo2                          0
# promo2_since_week               0
# promo2_since_year               0
# promo_interval                  0
# month_map                       0
# is_promo                        0
# dtype: int64

# %% [markdown]
# ## 2.5. Change the Columns Data Types

# %%
df2.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# month_map                               object
# is_promo                                 int64
# dtype: object

# %%
# change competition data - Month and Year
df2['competition_open_since_month'] = df2['competition_open_since_month'].astype( int )
df2['competition_open_since_year'] = df2['competition_open_since_year'].astype( int )

# change competition data - Week
df2['promo2_since_week'] = df2['promo2_since_week'].astype( int )
df2['promo2_since_year'] = df2['promo2_since_year'].astype( int )

# %%
df2.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month             int64
# competition_open_since_year              int64
# promo2                                   int64
# promo2_since_week                        int64
# promo2_since_year                        int64
# promo_interval                          object
# month_map                               object
# is_promo                                 int64
# dtype: object

# %% [markdown]
# ## 2.6. Descriptive statistics

# %%
# separate the categorical from numerical features
num_attributes = df2.select_dtypes( include=['int64', 'float64'] )
cat_attributes = df2.select_dtypes( exclude=['int64', 'float64', 'datetime64[ns]'] )
dat_attributes = df2.select_dtypes( include=['datetime64[ns]'] )

print( 'Num of Categorical: {}'.format( cat_attributes.shape[1] ) )
print( 'Num of Numerical: {}'.format( num_attributes.shape[1] ) )
print( 'Num of Date: {}'.format( dat_attributes.shape[1] ) )
# Out:
# Num of Categorical: 5
# Num of Numerical: 14
# Num of Date: 1

# %% [markdown]
# ### 2.6.1. Central Tendency and Dispersion

# %% [markdown]
# #### 2.6.1.1. Numerical Attributes

# %%
# Meausure of Central Tendency
ct1 = pd.DataFrame( num_attributes.apply( mean ) ).T
ct2 = pd.DataFrame( num_attributes.apply( median ) ).T


# Dispersion
d1 = pd.DataFrame( num_attributes.apply( std ) ).T
d2 = pd.DataFrame( num_attributes.apply( min ) ).T
d3 = pd.DataFrame( num_attributes.apply( max ) ).T
d4 = pd.DataFrame( num_attributes.apply( lambda x: x.max() - x.min() ) ).T
d5 = pd.DataFrame( num_attributes.apply( lambda x: x.kurtosis() ) ).T
d6 = pd.DataFrame( num_attributes.apply( lambda x: x.skew() ) ).T

m = pd.concat( [ d2, d3, d4, ct1, ct2, d1, d5, d6] ).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'standard_deviation', 'kurtosis', 'skew']

m
# Out:
#                       attributes     min       max     range         mean  median  standard_deviation    kurtosis       skew
# 0                          store     1.0    1115.0    1114.0   558.429727   558.0          321.908493   -1.200524  -0.000955
# 1                    day_of_week     1.0       7.0       6.0     3.998341     4.0            1.997390   -1.246873   0.001593
# 2                          sales     0.0   41551.0   41551.0  5773.818972  5744.0         3849.924283    1.778375   0.641460
# 3                      customers     0.0    7388.0    7388.0   633.145946   609.0          464.411506    7.091773   1.598650
# 4                           open     0.0       1.0       1.0     0.830107     1.0            0.375539    1.090723  -1.758045
# 5                          promo     0.0       1.0       1.0     0.381515     0.0            0.485758   -1.762018   0.487838
# 6                 school_holiday     0.0       1.0       1.0     0.178647     0.0            0.383056    0.815154   1.677842
# 7           competition_distance    20.0  200000.0  199980.0  5935.442677  2330.0        12547.646829  147.789712  10.242344
# 8   competition_open_since_month     1.0      12.0      11.0     6.786849     7.0            3.311085   -1.232607  -0.042076
# 9    competition_open_since_year  1900.0    2015.0     115.0  2010.324840  2012.0            5.515591  124.071304  -7.235657
# 10                        promo2     0.0       1.0       1.0     0.500564     1.0            0.500000   -1.999999  -0.002255
# 11             promo2_since_week     1.0      52.0      51.0    23.619033    22.0           14.310057   -1.184046   0.178723
# 12             promo2_since_year  2009.0    2015.0       6.0  2012.793297  2013.0            1.662657   -0.210075  -0.784436
# 13                      is_promo     0.0       1.0       1.0     0.161100     0.0            0.367623    1.399388   1.843742

# %% [markdown]
# ### 2.6.1.2. Categorical Attributes

# %%
c = pd.DataFrame( cat_attributes.apply( lambda x: x.unique().shape[0], axis=0 ).reset_index() )
c.columns = ['Columns Names', 'Number of Levels']
print( c )
# Out:
#     Columns Names  Number of Levels
# 0   state_holiday                 5
# 1      store_type                 4
# 2      assortment                 3
# 3  promo_interval                 4
# 4       month_map                12

# %%
plt.subplot( 1, 3, 1 )
sns.boxplot( x='state_holiday', y='sales', data=df2 );

plt.subplot( 1, 3, 2 )
sns.boxplot( x='store_type', y='sales', data=df2 );

plt.subplot( 1, 3, 3 )
sns.boxplot( x='assortment', y='sales', data=df2 );

# %% [markdown]
# # 3.0. FEATURE ENGINEERING
# ---

# %%
df3 = df2.copy()

# %% [markdown]
# ## 3.1. Feature Creation

# %%
# year
df3['year'] = df3['date'].dt.year

# month
df3['month'] = df3['date'].dt.month

# day
df3['day'] = df3['date'].dt.day

# week of year
df3['week_of_year'] = df3['date'].dt.weekofyear

# state_holiday
df3['state_holiday'] = df3['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christmas' if x == 'c' else 'regular_day' ) 

# assortment
df3['assortment'] = df3['assortment'].apply( lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended' )

# competition weeks
df3['month_of_competition'] = 12*( df3['year'] - df3['competition_open_since_year'] ) + ( df3['month'] - df3['competition_open_since_month'] )
df3['month_of_competition'] = df3['month_of_competition'].apply( lambda x: x if x > 0 else 0 )

# promomotion weeks
df3['month_of_promo'] = 12*( df3['year'] - df3['promo2_since_year'] ) + ( df3['week_of_year'] - df3['promo2_since_week'] )/4
df3['month_of_promo'] = df3['month_of_promo'].apply( lambda x: x if x > 0 else 0 )

# %% [markdown]
# # 4.0. SELECT FEATURES
# ---

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1. Filtering Rows

# %%
# only use data of Sales > 0 and Open is 1
df4 = df4[ (df4['open'] != 0) & (df4['sales'] > 0) ]

# %% [markdown]
# ## 4.2. Selecting Columns

# %% [markdown]
# **Columns to Drop**
# 1. **date**: foram derivados novas features da variavel date
# 2. **customers**: voce nao sabe o numero de clientes no momento da predicao
# 3. **open**: todas as linhas sao open
# 4. **promo interval**: foram derivadas novas features
# 5. **month map**: variável auxiliar

# %%
cols_drop = ['customers', 'open', 'promo_interval', 'month_map']

# drop columns
df4 = df4.drop( cols_drop, axis=1 )

# %%
df4.head(3)
# Out:
#    store  day_of_week       date  sales  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year  is_promo  year  month  day  week_of_year  month_of_competition  month_of_promo
# 0      1            5 2015-07-31   5263      1   regular_day               1          c      basic                1270.0                             9                         2008       0                 31               2015         0  2015      7   31            31                    82            0.00
# 1      2            5 2015-07-31   6064      1   regular_day               1          a      basic                 570.0                            11                         2007       1                 13               2010         1  2015      7   31            31                    92           64.50
# 2      3            5 2015-07-31   8314      1   regular_day               1          a      basic               14130.0                            12                         2006       1                 14               2011         1  2015      7   31            31                   103           52.25

# %% [markdown]
# # 5.0. EXPLORATION DATA ANALYSIS
# ---

# %%
df5 = df4.copy()

# %%
# separate the categorical from numerical features
num_attributes = df5.select_dtypes( include=['int64', 'float64'] )
cat_attributes = df5.select_dtypes( exclude=['int64', 'float64', 'datetime64[ns]'] )
dat_attributes = df5.select_dtypes( include=['datetime64[ns]'] )

print( 'Num of Categorical: {}'.format( cat_attributes.shape[1] ) )
print( 'Num of Numerical: {}'.format( num_attributes.shape[1] ) )
print( 'Num of Date: {}'.format( dat_attributes.shape[1] ) )
# Out:
# Num of Categorical: 3
# Num of Numerical: 18
# Num of Date: 1

# %% [markdown]
# ## 5.1. Univariate Analysis

# %% [markdown]
# ### 5.1.1. Response Variable

# %%
plt.subplot( 1, 2, 1 )
sns.distplot( df5['sales'], kde=True, bins=42 )

plt.subplot( 1, 2, 2 )
sns.distplot( np.log1p( df5['sales'] ), kde=True )

# %% [markdown]
# ### 5.1.2. Numerical Predictors

# %%
plt.subplot( 2, 3, 1 )
sns.distplot( df5['day_of_week'], kde=False );

plt.subplot( 2, 3, 2 )
sns.distplot( df5['promo'], kde=False );

plt.subplot( 2, 3, 3 )
sns.distplot( df5['school_holiday'], kde=False );

plt.subplot( 2, 3, 4 )
sns.distplot( df5['competition_distance'], kde=False );

plt.subplot( 2, 3, 5 )
sns.distplot( df5['competition_open_since_month'], kde=False );

plt.subplot( 2, 3, 6 )
sns.distplot( df5['competition_open_since_year'], kde=False );

# %%
num_attributes.head()
# Out:
#    store  day_of_week  sales  promo  school_holiday  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year  is_promo  year  month  day  week_of_year  month_of_competition  month_of_promo
# 0      1            5   5263      1               1                1270.0                             9                         2008       0                 31               2015         0  2015      7   31            31                    82            0.00
# 1      2            5   6064      1               1                 570.0                            11                         2007       1                 13               2010         1  2015      7   31            31                    92           64.50
# 2      3            5   8314      1               1               14130.0                            12                         2006       1                 14               2011         1  2015      7   31            31                   103           52.25
# 3      4            5  13995      1               1                 620.0                             9                         2009       0                 31               2015         0  2015      7   31            31                    70            0.00
# 4      5            5   4822      1               1               29910.0                             4                         2015       0                 31               2015         0  2015      7   31            31                     3            0.00

# %%
plt.subplot( 2, 3, 1 )
sns.distplot( df5['promo2'], kde=False );

plt.subplot( 2, 3, 2 )
sns.distplot( df5['promo2_since_week'], kde=False );

plt.subplot( 2, 3, 3 )
sns.distplot( df5['promo2_since_year'], kde=False );

plt.subplot( 2, 3, 4 )
sns.distplot( df5['is_promo'], kde=False );

plt.subplot( 2, 3, 5 )
sns.distplot( df5['year'], kde=False );

plt.subplot( 2, 3, 6 )
sns.distplot( df5['month'], kde=False );

# %%
plt.subplot( 2, 2, 1 )
sns.distplot( df5['day'], kde=False );

plt.subplot( 2, 2, 2 )
sns.distplot( df5['week_of_year'], kde=False );

plt.subplot( 2, 2, 3 )
sns.distplot( df5['month_of_competition'], kde=False );

plt.subplot( 2, 2, 4 )
sns.distplot( df5['month_of_promo'], kde=False );

# %% [markdown]
# ### 5.1.3. Categorical Predictors

# %%
cat_attributes.head()
# Out:
#   state_holiday store_type assortment
# 0   regular_day          c      basic
# 1   regular_day          a      basic
# 2   regular_day          a      basic
# 3   regular_day          c   extended
# 4   regular_day          a      basic

# %%
plt.subplot( 1, 3, 1 )
sns.countplot( x='store_type', data=df5 )

plt.subplot( 1, 3, 2 )
sns.countplot( x='assortment', data=df5 )

plt.subplot( 1, 3, 3 )
sns.countplot( x='state_holiday', data=df5 )

# %% [markdown]
# ## 5.2. Bivariate Analysis

# %% [markdown]
# ### 5.2.1. Numerical Predictors

# %%
# -------------------
# day of week
# -------------------
aux1 = df5[['day_of_week', 'sales']].groupby( 'day_of_week' ).sum().reset_index()
cor1 = aux1.corr( method='pearson' )
plt.subplot( 3, 3, 1 )
sns.barplot( x='day_of_week', y='sales', data=aux1 )

plt.subplot( 3, 3, 2 )
sns.regplot( x='day_of_week', y='sales', data=aux1 )

plt.subplot( 3, 3, 3 )
sns.heatmap( cor1, annot=True )

# ----------------------------
# competition open since month
# ----------------------------
aux3 = df5[['competition_open_since_month', 'sales']].groupby( 'competition_open_since_month' ).sum().reset_index()
cor3 = aux3.corr( method='pearson' )

plt.subplot( 3, 3, 4 )
sns.barplot( x='competition_open_since_month', y='sales', data=aux3 )

plt.subplot( 3, 3, 5 )
sns.regplot( x='competition_open_since_month', y='sales', data=aux3 )

plt.subplot( 3, 3, 6 )
sns.heatmap( cor3, annot=True )

# -------------------
# competition distance
# -------------------
aux2 = df5[['competition_distance', 'sales']].groupby( 'competition_distance' ).sum().reset_index()
cor2 = aux2.corr( method='pearson' )

bins = list( np.arange( 0, 20000, 1000 ) )
aux2['distance_binned'] = pd.cut( aux2['competition_distance'], bins=bins )
aux3 = aux2[['distance_binned', 'sales']].groupby( 'distance_binned' ).sum().reset_index()

plt.subplot( 3, 3, 7 )
sns.barplot( x='distance_binned', y='sales', data=aux3 )
plt.xticks( rotation=90 )

plt.subplot( 3, 3, 8 )
sns.scatterplot( x='competition_distance', y='sales', data=aux2 )

plt.subplot( 3, 3, 9 )
sns.heatmap( cor2, annot=True )

# %%
# ----------------------------
# competition open since year
# ----------------------------
aux1 = df5[['competition_open_since_year', 'sales']].groupby( 'competition_open_since_year' ).sum().reset_index()
cor1 = aux1.corr( method='pearson' )

plt.subplot( 3, 3, 1 )
sns.barplot( x='competition_open_since_year', y='sales', data=aux1 )
plt.xticks( rotation=90 )

plt.subplot( 3, 3, 2 )
sns.regplot( x='competition_open_since_year', y='sales', data=aux1 )

plt.subplot( 3, 3, 3 )
sns.heatmap( cor1, annot=True )

# -------------------
# promo2 since week
# -------------------
aux1 = df5[['promo2_since_week', 'sales']].groupby( 'promo2_since_week' ).sum().reset_index()
cor1 = aux1.corr( method='pearson' )
plt.subplot( 3, 3, 4 )
sns.barplot( x='promo2_since_week', y='sales', data=aux1 )
plt.xticks( rotation=90 )

plt.subplot( 3, 3, 5 )
sns.regplot( x='promo2_since_week', y='sales', data=aux1 )

plt.subplot( 3, 3, 6 )
sns.heatmap( cor1, annot=True )

# -------------------
# promo2 since year
# -------------------
aux1 = df5[['promo2_since_year', 'sales']].groupby( 'promo2_since_year' ).sum().reset_index()
cor1 = aux1.corr( method='pearson' )
plt.subplot( 3, 3, 7 )
sns.barplot( x='promo2_since_year', y='sales', data=aux1 )

plt.subplot( 3, 3, 8 )
sns.regplot( x='promo2_since_year', y='sales', data=aux1 )

plt.subplot( 3, 3, 9 )
sns.heatmap( cor1, annot=True )

# %%
# ----------------------------
# year
# ----------------------------
aux1 = df5[['year', 'sales']].groupby( 'year' ).sum().reset_index()
cor1 = aux1.corr( method='pearson' )

plt.subplot( 3, 3, 1 )
sns.barplot( x='year', y='sales', data=aux1 )

plt.subplot( 3, 3, 2 )
sns.regplot( x='year', y='sales', data=aux1 )

plt.subplot( 3, 3, 3 )
sns.heatmap( cor1, annot=True )

# -------------------
# month
# -------------------
aux1 = df5[['month', 'sales']].groupby( 'month' ).sum().reset_index()
cor1 = aux1.corr( method='pearson' )
plt.subplot( 3, 3, 4 )
sns.barplot( x='month', y='sales', data=aux1 )

plt.subplot( 3, 3, 5 )
sns.regplot( x='month', y='sales', data=aux1 )

plt.subplot( 3, 3, 6 )
sns.heatmap( cor1, annot=True )

# -------------------
# day
# -------------------
aux1 = df5[['day', 'sales']].groupby( 'day' ).sum().reset_index()
cor1 = aux1.corr( method='pearson' )
plt.subplot( 3, 3, 7 )
sns.barplot( x='day', y='sales', data=aux1 )

plt.subplot( 3, 3, 8 )
sns.regplot( x='day', y='sales', data=aux1 )

plt.subplot( 3, 3, 9 )
sns.heatmap( cor1, annot=True )

# %%
# ----------------------------
# week_of_year
# ----------------------------
aux1 = df5[['week_of_year', 'sales']].groupby( 'week_of_year' ).sum().reset_index()
cor1 = aux1.corr( method='pearson' )

plt.subplot( 3, 3, 1 )
sns.barplot( x='week_of_year', y='sales', data=aux1 )

plt.subplot( 3, 3, 2 )
sns.regplot( x='week_of_year', y='sales', data=aux1 )

plt.subplot( 3, 3, 3 )
sns.heatmap( cor1, annot=True )

# -------------------
# month of competition
# -------------------
aux1 = df5[['month_of_competition', 'sales']].groupby( 'month_of_competition' ).sum().reset_index()
cor1 = aux1.corr( method='pearson' )
plt.subplot( 3, 3, 4 )
sns.barplot( x='month_of_competition', y='sales', data=aux1 )

plt.subplot( 3, 3, 5 )
sns.regplot( x='month_of_competition', y='sales', data=aux1 )

plt.subplot( 3, 3, 6 )
sns.heatmap( cor1, annot=True )

# -------------------
# month_of_promo
# -------------------
aux1 = df5[['month_of_promo', 'sales']].groupby( 'month_of_promo' ).sum().reset_index()
cor1 = aux1.corr( method='pearson' )
plt.subplot( 3, 3, 7 )
sns.barplot( x='month_of_promo', y='sales', data=aux1 )

plt.subplot( 3, 3, 8 )
sns.regplot( x='month_of_promo', y='sales', data=aux1 )

plt.subplot( 3, 3, 9 )
sns.heatmap( cor1, annot=True )

# %% [markdown]
# ### 5.2.2. Categorical Predictors

# %%
cat_attributes.head()
# Out:
#   state_holiday store_type assortment
# 0   regular_day          c      basic
# 1   regular_day          a      basic
# 2   regular_day          a      basic
# 3   regular_day          c   extended
# 4   regular_day          a      basic

# %%
# Assortment X Sales
plt.subplot( 2, 2, 1 )
sns.boxplot( x='assortment', y='sales', data=df5 )

plt.subplot( 2, 2, 2 )
sns.kdeplot( df5[df5['assortment'] == 'basic']['sales'], label='basic', shade=True );
sns.kdeplot( df5[df5['assortment'] == 'extra']['sales'], label='extra', shade=True );
sns.kdeplot( df5[df5['assortment'] == 'extended']['sales'], label='extended', shade=True );

# State Holiday X Sales
plt.subplot( 2, 2, 3 )
sns.boxplot( x='state_holiday', y='sales', data=df5 )

plt.subplot( 2, 2, 4 )
sns.kdeplot( df5[df5['state_holiday'] == 'regular_day']['sales'], label='regular_day', shade=True );
sns.kdeplot( df5[df5['state_holiday'] == 'public_holiday']['sales'], label='public_holiday', shade=True );
sns.kdeplot( df5[df5['state_holiday'] == 'easter_holiday']['sales'], label='easter_holiday', shade=True );

# %% [markdown]
# ## 5.3. Multivariate Analysis

# %%
correlation = num_attributes.corr()
sns.heatmap( correlation, annot=True, fmt='.2f' )

plt.show()

# %% [markdown]
# # 6.0. DATA PREPARATION
# ---

# %%
df6 = df5.copy()

# %% [markdown]
# ## 6.1. Numerical Predictors

# %% [markdown]
# ### 6.1.1. Normalization ( Rescaling )

# %%
mms = MinMaxScaler()

# %%
# competition distance
df6['competition_distance'] = mms.fit_transform( df6[['competition_distance']].values )
save_parameter_encoder( mms, 'competition_distance', 'minmax' )

# month of promotion
df6['month_of_promo'] = mms.fit_transform( df6[['month_of_promo']].values )
save_parameter_encoder( mms, 'month_of_promo', 'minmax' )

# competition open since year
df6['competition_open_since_year'] = mms.fit_transform( df6[['competition_open_since_year']].values ) 
save_parameter_encoder( mms, 'competition_open_since_year', 'minmax' )

# year
df6['year'] = mms.fit_transform( df6[['year']].values ) 
save_parameter_encoder( mms, 'year', 'minmax' )

# promo2 since year
df6['promo2_since_year'] = mms.fit_transform( df6[['promo2_since_year']].values )
save_parameter_encoder( mms, 'promo2_since_year', 'minmax' )

# month_of_competiton
df6['month_of_competition'] = mms.fit_transform( df6[['month_of_competition']].values )
save_parameter_encoder( mms, 'month_of_competition', 'minmax' )

# %% [markdown]
# ### 6.1.2. Transformations

# %%
# day of week
df6['day_of_week_sin'] = df6['day_of_week'].apply( lambda x: np.sin( x * ( 2. * np.pi/7 ) ) )
df6['day_of_week_cos'] = df6['day_of_week'].apply( lambda x: np.cos( x * ( 2. * np.pi/7 ) ) )

# competition open since month
df6['competition_open_since_month_sin'] = df6['competition_open_since_month'].apply( lambda x: np.sin( x * ( 2. * np.pi/12 ) ) )
df6['competition_open_since_month_cos'] = df6['competition_open_since_month'].apply( lambda x: np.cos( x * ( 2. * np.pi/12 ) ) )

# promo 2 since week
df6['promo2_since_week_sin'] = df6['promo2_since_week'].apply( lambda x: np.sin( x * ( 2. * np.pi/52 ) ) )
df6['promo2_since_week_cos'] = df6['promo2_since_week'].apply( lambda x: np.cos( x * ( 2. * np.pi/52 ) ) )

# month
df6['month_sin'] = df6['month'].apply( lambda x: np.sin( x * ( 2. * np.pi/12 ) ) )
df6['month_cos'] = df6['month'].apply( lambda x: np.cos( x * ( 2. * np.pi/12 ) ) )

# day
df6['day_sin'] = df6['day'].apply( lambda x: np.sin( x * ( 2. * np.pi/31 ) ) )
df6['day_cos'] = df6['day'].apply( lambda x: np.cos( x * ( 2. * np.pi/31 ) ) )

# week_of_year
df6['week_of_year_sin'] = df6['week_of_year'].apply( lambda x: np.sin( x * ( 2. * np.pi/52 ) ) )
df6['week_of_year_cos'] = df6['week_of_year'].apply( lambda x: np.cos( x * ( 2. * np.pi/52 ) ) )

df6 = df6.drop( ['day_of_week', 'competition_open_since_month', 'promo2_since_week', 'month', 'day', 'week_of_year'], axis=1 )

# %% [markdown]
# ## 6.2. Categorical Predictors

# %% [markdown]
# ### 6.2.1. Label Encoding

# %%
# Label Encoder
le = LabelEncoder()

# state holiday
df6['state_holiday'] = df6['state_holiday'].apply( lambda x: 1 if x == 'regular_day' else 0 )
df6 = df6.rename( columns={'state_holiday':'regular_day'})

# store_type
df6['store_type'] = le.fit_transform( df6['store_type'] )
save_parameter_encoder( le, 'store_type', 'label_encoder' )

# assortment
df6['assortment'] = le.fit_transform( df6['assortment'] )
save_parameter_encoder( le, 'assortment', 'label_encoder' )

# %% [markdown]
# ## 6.3. Response Variable

# %% [markdown]
# ### 6.3.1. Transformations

# %%
# Log transformation
df6['sales'] =  np.log1p( df6['sales'] )

# %%
df6.sample( 3 )
# Out:
#         store       date     sales  promo  regular_day  school_holiday  store_type  assortment  competition_distance  competition_open_since_year  promo2  promo2_since_year  is_promo  year  month_of_competition  month_of_promo  day_of_week_sin  day_of_week_cos  competition_open_since_month_sin  competition_open_since_month_cos  promo2_since_week_sin  promo2_since_week_cos  month_sin     month_cos   day_sin   day_cos  week_of_year_sin  week_of_year_cos
# 103291    712 2015-04-30  9.047233      1            1               0           0           0              0.024252                     0.930435       1           0.000000         1   1.0              0.065657        0.906250        -0.433884        -0.900969                         -1.000000                     -1.836970e-16              -0.748511               0.663123   0.866025 -5.000000e-01 -0.201299  0.979530          0.822984         -0.568065
# 945838   1104 2013-03-06  8.600431      1            1               0           3           0              0.001200                     0.973913       1           0.333333         0   0.0              0.009380        0.319444         0.433884        -0.900969                          0.866025                      5.000000e-01               0.992709              -0.120537   1.000000  6.123234e-17  0.937752  0.347305          0.935016          0.354605
# 520927   1008 2014-03-22  8.349248      0            1               0           0           1              0.000050                     0.956522       0           0.833333         0   0.5              0.030303        0.000000        -0.781831         0.623490                         -1.000000                     -1.836970e-16               0.992709               0.120537   1.000000  6.123234e-17 -0.968077 -0.250653          0.992709          0.120537

# %% [markdown]
# # 7.0. FEATURE SELECTION
# ---

# %%
df7 = df6.copy()

# %% [markdown]
# ## 7.1. Split training and test dataset

# %%
# split the last 6 weeks data as hold-out set
df7 = df7.sort_values( 'date', ascending=False )

## split training and test dataset
# training
X = df7[6*7*1115:]
y = X['sales']

# test
X_test = df7[:6*7*1115]
y_test = X_test['sales']

# %% [markdown]
# ## 7.2. Boruta Feature Selection

# %%
X_train_n = X.drop( ['sales', 'date'], axis=1 ).values
y_train_n = y.values.ravel()

# define random forest regressor
rf = RandomForestRegressor( n_jobs=-1 )

# define Boruta features selection method
boruta = BorutaPy( rf, n_estimators='auto', verbose=2, random_state=1 ).fit( X_train_n, y_train_n )

# selecting features based on the chosen ranking
rank_list = [1]
cols_selected = [ True if x in rank_list else False for x in boruta.ranking_ ]

# select the best features
cols_selected_boruta = X_train_fs.iloc[:, cols_selected].columns.to_list()

# features selected and not selected
cols_not_selected_boruta = list( np.setdiff1d( X_train_fs.columns, cols_selected_boruta ) )

# %% [markdown]
# ## 7.3. Manual Feature Selection

# %%
cols_selected_boruta =  ['store', 'store_type', 'assortment', 'promo', 'month_of_promo', 'promo2', 'promo2_since_year', 'promo2_since_week_sin', 'promo2_since_week_cos', 'competition_distance', 
    'competition_open_since_month_sin', 'competition_open_since_month_cos', 'competition_open_since_year', 'month_of_competition', 'day_of_week_sin', 'day_of_week_cos', 'day_sin', 'day_cos', 
    'month_cos', 'week_of_year_cos']

cols_not_selected_boruta = ['regular_day', 'state_holiday', 'school_holiday', 'is_promo', 'year', 'month_sin', 'week_of_year_sin']

# %% [markdown]
# ## 7.4. Final Selected Features

# %%
# features to delete
feat_to_delete = ['month_cos', 'week_of_year_cos']
feat_to_add = ['date', 'sales']

# features to add
cols_selected_boruta.extend( feat_to_add )

# new columns
new_feat = [ f for f in cols_selected_boruta if f not in feat_to_delete ]

# %% [markdown]
# # 8.0. MACHINE LEARNING MODELLING
# ---

# %%
# training and test dataset for cross-validation
X_train = X[ new_feat ]
X_test = X_test[ new_feat ]

# Training and test dataset for training
X_train_n = X_train.drop( ['date', 'sales'], axis=1 )
y_train_n = X_train['sales']

X_test_n = X_test.drop( ['date', 'sales'], axis=1 )
y_test_n = X_test['sales']

# define dates to nested cross-validation
training_start = datetime( 2013, 1, 1 )
training_end = datetime( 2015, 1, 13 )
holdout_end = datetime( 2015, 6, 13 )

# number of folds
k = 5

# %% [markdown]
# ## 8.1. Average Model ( Baseline Model )

# %%
# dataset
aux = X_test.copy()
aux['sales'] = y_test.copy()

# predictions
yhat_store = aux[['store', 'sales']].groupby( 'store' ).mean().reset_index().rename( columns={'sales':'predictions'} )
aux1 = pd.merge( aux, yhat_store, how='left', on='store')
yhat_baseline = aux1['predictions']

# performance 
baseline_result = ml_error( 'Average Model', np.expm1( y_test ), np.expm1( yhat_baseline ) )
print( baseline_result )
# Out:
#            Model          MAE      MAPE         RMSE     RMSPE
# 0  Average Model  1400.295276  0.472481  1878.694596  0.726751

# %% [markdown]
# ## 8.2. Linear Regression

# %%
# model
lr = LinearRegression().fit( X_train_n, y_train_n )

# predictions
yhat_lr = lr.predict( X_test_n )

# performance 
lr_result = ml_error( 'Linear Regression', np.expm1( y_test_n ), np.expm1( yhat_lr ) )
print( lr_result )
# Out:
#                Model          MAE      MAPE         RMSE     RMSPE
# 0  Linear Regression  1902.030569  0.297662  2700.120445  0.440672

# %% [markdown]
# ### 8.2.1. Cross Validation

# %%
# modelling
lr = LinearRegression()

# nested cross-validation
lr_cv = nested_cross_validation( training_start, training_end, holdout_end, k, X_train, lr, verbose=0 )

lr_avg_rmspe_cv = np.round( lr_cv['AVG RMSPE'], 2 ).astype( str ) + ' +/- ' + np.round( lr_cv['STD RMSPE'], 2 ).astype( str ) 
lr_avg_rmse_cv = np.round( lr_cv['AVG RMSE'], 2 ).astype( str ) + ' +/- ' + np.round( lr_cv['STD RMSE'], 2 ).astype( str )
lr_avg_mae_cv = np.round( lr_cv['AVG MAE'], 2 ).astype( str ) + ' +/- ' + np.round( lr_cv['STD MAE'], 2 ).astype( str )
lr_avg_mape_cv = np.round( lr_cv['AVG MAPE'], 2 ).astype( str ) + ' +/- ' + np.round( lr_cv['STD MAPE'], 2 ).astype( str )

lr_result_cv = pd.DataFrame( {'Model': 'Linear Regression', 'AVG MAE': lr_avg_mae_cv, 'AVG MAPE': lr_avg_mape_cv, 'AVG RMSE': lr_avg_rmse_cv, 'AVG RMSPE': lr_avg_rmspe_cv}, index=[0] )
print( lr_result_cv )
# Out:
#                Model            AVG MAE      AVG MAPE            AVG RMSE      AVG RMSPE
# 0  Linear Regression  1916.47 +/- 96.33  0.3 +/- 0.01  2723.33 +/- 198.34  0.45 +/- 0.05

# %% [markdown]
# ## 8.3. Linear Regression Regularized

# %%
# model
lrr = Lasso( alpha=0.01 ).fit( X_train_n, y_train_n )

# predictions
yhat_lrr = lrr.predict( X_test_n )

# performance 
lrr_result = ml_error( 'Linear Regression Lasso', np.expm1( y_test_n ), np.expm1( yhat_lrr ) )
print( lrr_result )
# Out:
#                      Model          MAE      MAPE        RMSE     RMSPE
# 0  Linear Regression Lasso  1940.105107  0.288984  2821.55795  0.421829

# %% [markdown]
# ### 8.3.1. Cross Validation

# %%
# modeling
lrr = Lasso( alpha=0.01 )

# nested cross-validation
lrr_cv = nested_cross_validation( training_start, training_end, holdout_end, k, X_train, lrr, verbose=0 )

lrr_avg_rmspe_cv = np.round( lrr_cv['AVG RMSPE'], 2 ).astype( str ) + ' +/- ' + np.round( lrr_cv['STD RMSPE'], 2 ).astype( str ) 
lrr_avg_rmse_cv = np.round( lrr_cv['AVG RMSE'], 2 ).astype( str ) + ' +/- ' + np.round( lrr_cv['STD RMSE'], 2 ).astype( str )
lrr_avg_mae_cv = np.round( lrr_cv['AVG MAE'], 2 ).astype( str ) + ' +/- ' + np.round( lrr_cv['STD MAE'], 2 ).astype( str )
lrr_avg_mape_cv = np.round( lrr_cv['AVG MAPE'], 2 ).astype( str ) + ' +/- ' + np.round( lrr_cv['STD MAPE'], 2 ).astype( str )

lrr_result_cv = pd.DataFrame( {'Model': 'Linear Regression', 'AVG MAE': lrr_avg_mae_cv, 'AVG MAPE': lrr_avg_mape_cv, 'AVG RMSE': lrr_avg_rmse_cv, 'AVG RMSPE': lrr_avg_rmspe_cv}, index=[0] )
print( lrr_result_cv )
# Out:
#                Model             AVG MAE       AVG MAPE            AVG RMSE      AVG RMSPE
# 0  Linear Regression  1951.79 +/- 139.81  0.29 +/- 0.01  2818.66 +/- 243.29  0.44 +/- 0.04

# %% [markdown]
# ## 8.4. Random Forest Regressor

# %%
# model
rf = RandomForestRegressor( n_estimators=100, n_jobs=-1, random_state=0 ).fit( X_train_n, y_train_n )

# predictions
yhat_rf = rf.predict( X_test_n )

# performance
rf_result = ml_error( 'Random Forest Regressor', np.expm1( y_test_n ), np.expm1( yhat_rf ) )
print( rf_result )
# Out:
#                      Model         MAE      MAPE        RMSE     RMSPE
# 0  Random Forest Regressor  741.324122  0.109424  1082.67461  0.153336

# %% [markdown]
# ### 8.4.1. Cross Validation

# %%
# modeling
rf = RandomForestRegressor( n_estimators=100, n_jobs=-1, random_state=0 )

# nested cross-validation
rf_cv = nested_cross_validation( training_start, training_end, holdout_end, k, X_train, rf, verbose=1 )

rf_avg_rmspe_cv = np.round( rf_cv['AVG RMSPE'], 2 ).astype( str ) + ' +/- ' + np.round( rf_cv['STD RMSPE'], 2 ).astype( str ) 
rf_avg_rmse_cv = np.round( rf_cv['AVG RMSE'], 2 ).astype( str ) + ' +/- ' + np.round( rf_cv['STD RMSE'], 2 ).astype( str )
rf_avg_mae_cv = np.round( rf_cv['AVG MAE'], 2 ).astype( str ) + ' +/- ' + np.round( rf_cv['STD MAE'], 2 ).astype( str )
rf_avg_mape_cv = np.round( rf_cv['AVG MAPE'], 2 ).astype( str ) + ' +/- ' + np.round( rf_cv['STD MAPE'], 2 ).astype( str )

rf_result_cv = pd.DataFrame( {'Model': 'Random Forest Regression', 'AVG MAE': rf_avg_mae_cv, 'AVG MAPE': rf_avg_mape_cv, 'AVG RMSE': rf_avg_rmse_cv, 'AVG RMSPE': rf_avg_rmspe_cv}, index=[0] )
print( rf_result_cv )
# Out:
# Fold K: 1
# Fold K: 2
# Fold K: 3
# Fold K: 4
# Fold K: 5
#                       Model            AVG MAE       AVG MAPE            AVG RMSE     AVG RMSPE
# 0  Random Forest Regression  807.58 +/- 152.38  0.12 +/- 0.03  1217.41 +/- 216.74  0.2 +/- 0.05

# %% [markdown]
# ## 8.5. XGBoost Regressor

# %% [markdown]
# ### 8.5.1. Training

# %%
# model
xgb = xgboost.XGBRegressor( objective='reg:squarederror', n_estimators=100, eta=0.03, max_depth=10, subsample=0.9, colsample_bytree=0.7 ).fit( X_train_n, y_train_n )

# predictions
yhat_xgb = xgb.predict( X_test_n )

# performance
xgb_result = ml_error( 'XGBoost', np.expm1( y_test_n ), np.expm1( yhat_xgb ) )
print( xgb_result )
# Out:
#      Model         MAE      MAPE         RMSE     RMSPE
# 0  XGBoost  871.078996  0.129079  1248.688218  0.176142

# %% [markdown]
# ### 8.5.3. Cross Validation

# %%
# model
xgb = xgboost.XGBRegressor( objective='reg:squarederror', n_estimators=100, eta=0.03, max_depth=10, subsample=0.9, colsample_bytree=0.7 )

# modelling cross validation
xgb_cv = nested_cross_validation( training_start, training_end, holdout_end, k, X_train, xgb, verbose=1 )

xgb_avg_rmspe_cv = np.round( xgb_cv['AVG RMSPE'], 2 ).astype( str ) + ' +/- ' + np.round( xgb_cv['STD RMSPE'], 2 ).astype( str ) 
xgb_avg_rmse_cv = np.round( xgb_cv['AVG RMSE'], 2 ).astype( str ) + ' +/- ' + np.round( xgb_cv['STD RMSE'], 2 ).astype( str )
xgb_avg_mae_cv = np.round( xgb_cv['AVG MAE'], 2 ).astype( str ) + ' +/- ' + np.round( xgb_cv['STD MAE'], 2 ).astype( str )
xgb_avg_mape_cv = np.round( xgb_cv['AVG MAPE'], 2 ).astype( str ) + ' +/- ' + np.round( xgb_cv['STD MAE'], 2 ).astype( str )

xgb_result_cv = pd.DataFrame( {'Model': 'XGBoost Regression', 'AVG MAE': xgb_avg_mae_cv, 'AVG MAPE': xgb_avg_mape_cv, 'AVG RMSE': xgb_avg_rmse_cv, 'AVG RMSPE': xgb_avg_rmspe_cv}, index=[0] )

print( xgb_result_cv )
# Out:
# Fold K: 1
# Fold K: 2
# Fold K: 3
# Fold K: 4
# Fold K: 5
#                 Model           AVG MAE        AVG MAPE            AVG RMSE      AVG RMSPE
# 0  XGBoost Regression  954.04 +/- 99.19  0.14 +/- 99.19  1387.66 +/- 194.09  0.21 +/- 0.04

# %% [markdown]
# ## 8.6. Summary of Modelling

# %% [markdown]
# ### 8.6.1. Single test dataset

# %%
# results
modelling_result = pd.concat( [baseline_result, lr_result, lrr_result, rf_result, xgb_result] )
modelling_result.sort_values( 'MAE' )
# Out:
#                      Model          MAE      MAPE         RMSE     RMSPE
# 0  Random Forest Regressor   741.324122  0.109424  1082.674610  0.153336
# 0                  XGBoost   871.078996  0.129079  1248.688218  0.176142
# 0            Average Model  1400.295276  0.472481  1878.694596  0.726751
# 0        Linear Regression  1902.030569  0.297662  2700.120445  0.440672
# 0  Linear Regression Lasso  1940.105107  0.288984  2821.557950  0.421829

# %% [markdown]
# ### 8.6.2. Cross-Validation dataset

# %%
# cross validation results
modelling_results_cv = pd.concat( [lr_result_cv, lrr_result_cv, rf_result_cv, xgb_result_cv] )
modelling_results_cv
# Out:
#                       Model             AVG MAE        AVG MAPE            AVG RMSE      AVG RMSPE
# 0         Linear Regression   1916.47 +/- 96.33    0.3 +/- 0.01  2723.33 +/- 198.34  0.45 +/- 0.05
# 0         Linear Regression  1951.79 +/- 139.81   0.29 +/- 0.01  2818.66 +/- 243.29  0.44 +/- 0.04
# 0  Random Forest Regression   807.58 +/- 152.38   0.12 +/- 0.03  1217.41 +/- 216.74   0.2 +/- 0.05
# 0        XGBoost Regression    954.04 +/- 99.19  0.14 +/- 99.19  1387.66 +/- 194.09  0.21 +/- 0.04

# %% [markdown]
# # 9.0. FINE TUNNING MODELLING
# ---

# %% [markdown]
# ## 9.1. Random Search Tunning

# %%
# params dictionary
params = {
    'n_estimators': [1100, 1500, 1700],
    'max_depth': [3, 4, 5],
    'min_child_weight': [1, 5, 10],
    'eta': [0.1, 0.3],
    'subsample': [0.1, 0.5],
    'colsample_bytree': [0.6, 0.8, 1.0]
}

MAX_EVALS = 5

# %%
import random 

# dataframe for results
final_result = pd.DataFrame()
k = 5

# keep searching until reach max evaluations
for i in range( MAX_EVALS ):
    # choose random hyperparameters
    hp = {k: random.sample( v, 1)[0] for k, v in params.items() }
    print( hp )
    
    # model
    xgb = xgboost.XGBRegressor( objective = 'reg:squarederror', 
                                n_estimators = hp['n_estimators'], 
                                eta = hp['eta'], 
                                max_depth = hp['max_depth'], 
                                subsample = hp['subsample'],
                                min_child_weight = hp['min_child_weight'],
                                colsample_bytree = hp['colsample_bytree'] )

    # Evaluate randomly selected hyperparameters
    eval_result = nested_cross_validation( training_start, training_end, holdout_end, k, X_train, xgb, verbose=1 )
    
    # results
    aux1 = pd.DataFrame( eval_result, index=[0] )
    aux2 = pd.DataFrame( hp, index=[0] )
    aux3 = pd.concat( [aux1, aux2 ], axis=1 )
    
    final_result = pd.concat( [final_result, aux3], axis=0 )
    
final_result.sort_values( 'AVG MAE' )
# Out:
# {'n_estimators': 1100, 'max_depth': 4, 'min_child_weight': 10, 'eta': 0.1, 'subsample': 0.1, 'colsample_bytree': 1.0}
# Fold K: 1
# Fold K: 2
# Fold K: 3
# Fold K: 4
# Fold K: 5
# {'n_estimators': 1700, 'max_depth': 3, 'min_child_weight': 5, 'eta': 0.1, 'subsample': 0.1, 'colsample_bytree': 1.0}
# Fold K: 1
# Fold K: 2
# Fold K: 3
# Fold K: 4
# Fold K: 5
# {'n_estimators': 1100, 'max_depth': 4, 'min_child_weight': 1, 'eta': 0.3, 'subsample': 0.5, 'colsample_bytree': 1.0}
# Fold K: 1
# Fold K: 2
# Fold K: 3
# Fold K: 4
# Fold K: 5
# {'n_estimators': 1100, 'max_depth': 5, 'min_child_weight': 1, 'eta': 0.1, 'subsample': 0.1, 'colsample_bytree': 0.8}
# Fold K: 1
# Fold K: 2
# Fold K: 3
# Fold K: 4
# Fold K: 5
# {'n_estimators': 1700, 'max_depth': 3, 'min_child_weight': 5, 'eta': 0.1, 'subsample': 0.1, 'colsample_bytree': 0.6}
# Fold K: 1
# Fold K: 2
# Fold K: 3
# Fold K: 4
# Fold K: 5
#        AVG MAE     STD MAE  AVG MAPE  STD MAPE     AVG RMSE    STD RMSE  AVG RMSPE  STD RMSPE  n_estimators  max_depth  min_child_weight  eta  subsample  colsample_bytree
# 0   931.738690  116.249224  0.137091  0.013397  1330.965179  210.442821   0.208855   0.037179          1100          5                 1  0.1        0.1               0.8
# 0   972.243261  122.603622  0.142798  0.010071  1391.052189  227.398105   0.217660   0.032701          1100          4                 1  0.3        0.5               1.0
# 0   973.989945  116.587115  0.143166  0.010075  1388.003756  214.018856   0.216578   0.032345          1100          4                10  0.1        0.1               1.0
# 0  1047.301450  134.889367  0.153172  0.009809  1493.120879  247.230662   0.230436   0.030988          1700          3                 5  0.1        0.1               1.0
# 0  1055.077344  108.150185  0.154668  0.009558  1503.183725  201.854974   0.230481   0.030123          1700          3                 5  0.1        0.1               0.6

# %% [markdown]
# ## 9.2. Final Model Tunning

# %%
# params dictionary
param_tunned = {
    'n_estimators': 1100,
    'max_depth': 5,
    'min_child_weight': 1,
    'eta': 0.1,
    'subsample': 0.1,
    'colsample_bytree': 0.8
}

# %%
# final model
xgb_tunned = xgboost.XGBRegressor( objective='reg:squarederror', 
                                   n_estimators=param_tunned['n_estimators'], 
                                   eta=param_tunned['eta'], 
                                   max_depth=param_tunned['max_depth'], 
                                   max_child_weight=param_tunned['min_child_weight'],
                                   subsample=param_tunned['subsample'], 
                                   colsample_bytree=param_tunned['colsample_bytree'] ).fit( X_train_n, y_train_n )

# predictions
yhat_xgb_tunned = xgb_tunned.predict( X_test_n )

# performance
xgb_result_tunned = ml_error( 'XGBoost', np.expm1( y_test_n ), np.expm1( yhat_xgb_tunned ) )
print( xgb_result_tunned )
# Out:
#      Model         MAE      MAPE         RMSE    RMSPE
# 0  XGBoost  789.241754  0.117863  1112.717628  0.16212

# %% [markdown]
# # 10.0. ERROR INTEPRETATION
# ---

# %%
df10 = X_test.copy()

# %%
# add the predictions
df10['predictions'] = yhat_xgb_tunned

# Transform response variables back to original scale
df10['sales'] = np.expm1( df10['sales'] )
df10['predictions'] = np.round( np.expm1( df10['predictions'] ) )

# compute the error
df10['error'] = df10['sales'] - df10['predictions']
df10['error_type'] = df10['error'].apply( lambda x: 'underestimate' if x > 0 else 'overestimate' )
df10['error_ratio'] = df10['predictions']/df10['sales'] 

## compute the error by store
#aux = df10[['store', 'sales', 'predictions']].groupby( 'store' ).sum().reset_index()
#aux['mape'] = aux.apply( lambda x: mean_absolute_percentage_error( x['sales'], x['predictions'] ) )

# %% [markdown]
# ## 10.1. Model Performance

# %%
#a = df10[df10['store'] == 255][['date', 'sales', 'predictions', 'error', 'error_ratio', 'error_type']]

# %%
sales_total = np.round( np.sum( df10['sales'] ) )
pred_total = np.round( np.sum( df10['predictions'] ) )

sales_avg = np.round( np.mean( df10['sales'] ) )
sales_std = np.round( np.std( df10['sales'] ) )
sales_min = np.round( np.min( df10['sales'] ) )
sales_max = np.round( np.max( df10['sales'] ) )

mape = mean_absolute_percentage_error( df10['sales'], df10['predictions'] )
mpe = mean_percentage_error( df10['sales'], df10['predictions'])
mae = np.round( mean_absolute_error( df10['sales'], df10['predictions'] ), 2 )

print( 'Total Sales: {}'.format( sales_total ) )
print( 'Avg Sales: {} +/- {}'.format( sales_avg, sales_std ) )
print( 'Min: {}, Max:{}'.format( sales_min, sales_max ) )

print( '\nMAE: {}'.format( mae ) )
print( 'MAPE: {:.2f}%'.format( mape ) )
print( 'MPE: {:.2f}%'.format( mpe ) )
# Out:
# Total Sales: 333365121.0
# Avg Sales: 7119.0 +/- 3092.0
# Min: 569.0, Max:41551.0
#
# MAE: 789.24
# MAPE: 0.12%
# MPE: -0.03%

# %%
plt.subplot( 2, 2, 1 )
sns.lineplot( x='date', y='sales', data=df10, label='sales' )
sns.lineplot( x='date', y='predictions', data=df10, label='prediction' )
plt.legend()

plt.subplot( 2, 2, 2 )
sns.lineplot( x='date', y='error_ratio', data=df10 )
plt.axhline( 1, color='r', linestyle='--' )

plt.subplot( 2, 2, 3 )
sns.distplot( df10['error'] )

plt.subplot( 2, 2, 4 )
sns.scatterplot( df10['predictions'], df10['error'] )

# %% [markdown]
# ## 10.2. Business Performance

# %%
sales_total = np.round( df10['sales'].sum() )
pred_total = df10['predictions'].sum()

acc = 100*( 1 - ( ( sales_total - pred_total )/sales_total ) )

print( 'Total Sales in 6 weeks: {}'.format( sales_total ) )
print( 'Total Prediction in 6 weeks: {}'.format( pred_total ) )
print( 'ACC: {0:.2f}%'.format( acc ) )
# Out:
# Total Sales in 6 weeks: 333365121.0
# Total Prediction in 6 weeks: 333860480.0
# ACC: 100.15%

# %% [markdown]
# # 11.0. MODEL TO PRODUCTION
# ---

# %% [markdown]
# ## 11.1. Save Trained Model

# %%
# save the trained model
pickle.dump( xgb_tunned, open( '/Users/meigarom/repos/Predictive-Analytics/model/model_{}.pkl'.format( 'xgb' ), 'wb' ) )

# %% [markdown]
# # 12.0. MAKE PREDICTION
# ---

# %% [markdown]
# ## 12.2. Multiple Examples

# %%
test_raw = pd.read_csv( '../data/test.csv' )

# Merge dataset
df_test = pd.merge( test_raw, df_stores_raw, on='Store', how='left' )

# remove close days and undefined days
df_test = df_test[~df_test['Open'].isnull()]
df_test = df_test[df_test['Open'] != 0]

# %% [markdown]
# ### 12.2.1. Transform Method from Class

# %%
#df1 = df_test.copy()
#
## new columns name
#new_cols=['id', 'store', 'day_of_week', 'date', 'open', 'promo', 'state_holiday', 'school_holiday', 'store_type', 'assortment', 'competition_distance', 'competition_open_since_month', 
#          'competition_open_since_year', 'promo2', 'promo2_since_week', 'promo2_since_year', 'promo_interval']
#
## rename
#df1.columns = new_cols
#
## convert to datetime
#df1['date'] = pd.to_datetime( df1['date'] )
#
## --------------------
## ----- Treat NA -----
## --------------------
#
## promo2_since_year
#df1['promo2_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['promo2_since_year'] ) else x['promo2_since_year'], axis=1 )
#
## promo2_since_week
#df1['promo2_since_week'] = df1.apply( lambda x: x['date'].weekofyear if math.isnan( x['promo2_since_week'] ) else x['promo2_since_week'], axis=1 )
#
## competition_distance
#df1['competition_distance'] = df1['competition_distance'].apply( lambda x: 200000.0 if math.isnan( x ) else x )
#
## competition_open_since_month
#df1['competition_open_since_month'] = df1.apply( lambda x: x['date'].month if math.isnan( x['competition_open_since_month'] ) else x['competition_open_since_month'], axis=1 ) 
#
## competition_open_since_year
#df1['competition_open_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['competition_open_since_year'] ) else x['competition_open_since_year'], axis=1 )
#
## promo_interval
### fill na with 0
#df1.fillna( 0, inplace=True )
## if date is in the promo interval, there is promo.
#monthmap = {1:'Jan', 2:'Fev', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', 7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}
#df1['month_map'] = df1['date'].dt.month.map( monthmap )
#df1['is_promo'] = df1[['promo_interval', 'month_map']].apply( lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split( ',' ) else 0, axis=1 )
#
## ----------------------------
## ----- Change Data Type -----
## ----------------------------
## change competition data - Month and Year
#df1['competition_open_since_month'] = df1['competition_open_since_month'].astype( int )
#df1['competition_open_since_year'] = df1['competition_open_since_year'].astype( int )
#
## change competition data - Week
#df1['promo2_since_week'] = df1['promo2_since_week'].astype( int )
#df1['promo2_since_year'] = df1['promo2_since_year'].astype( int )
#
## ----------------------------
## ----- Create Features -----
## ----------------------------
## year
#df1['year'] = df1['date'].dt.year
#
## month
#df1['month'] = df1['date'].dt.month
#
## day
#df1['day'] = df1['date'].dt.day
#
## week of year
#df1['week_of_year'] = df1['date'].dt.weekofyear
#
## state_holiday
#df1['state_holiday'] = df1['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christmas' if x == 'c' else 'regular_day' ) 
#
## assortment
#df1['assortment'] = df1['assortment'].apply( lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended' )
#
## competition weeks
#df1['month_of_competition'] = 12*( df1['year'] - df1['competition_open_since_year'] ) + ( df1['month'] - df1['competition_open_since_month'] )
#df1['month_of_competition'] = df1['month_of_competition'].apply( lambda x: x if x > 0 else 0 )
#
## promomotion weeks
#df1['month_of_promo'] = 12*( df1['year'] - df1['promo2_since_year'] ) + ( df1['week_of_year'] - df1['promo2_since_week'] )/4
#df1['month_of_promo'] = df1['month_of_promo'].apply( lambda x: x if x > 0 else 0 )
#
## ----------------------------
## ------ Filtering Data ------
## ----------------------------
#df1 = df1[df1['open'] != 0]
#
## drop columns
#df1 = df1.drop( ['id', 'date', 'open', 'state_holiday', 'school_holiday', 'is_promo', 'year', 'month', 'week_of_year', 'promo_interval', 'month_map'], axis=1 )

# %% [markdown]
# ## 12.3. Final Results

# %%
# data
b = df_test.to_dict( orient='records' )
d = json.dumps( b )

# prediction request
#url = 'http://0.0.0.0:5000/rossmann/predict'
url = 'https://rossmann-model.herokuapp.com/rossmann/predict'
h = {'Content-type': 'application/json'}
r = requests.post( url, data=d, headers=h )
print( 'Request Status: {} code:{}'.format( r.status_code, r.status_code ) )
    
# results 
df_results = pd.DataFrame( r.json(), columns=list( r.json()[0].keys() ) )
# Out:
# Request Status: 200 code:200

# %%
df_results.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear    PromoInterval   Prediction
# 0   1      1          4  2015-09-17   1.0      1            0              0         c          a               1270.0                        9.0                    2008.0       0              NaN              NaN             None  4726.063965
# 1   2      3          4  2015-09-17   1.0      1            0              0         a          a              14130.0                       12.0                    2006.0       1             14.0           2011.0  Jan,Apr,Jul,Oct  6510.718750
# 2   3      7          4  2015-09-17   1.0      1            0              0         a          c              24000.0                        4.0                    2013.0       0              NaN              NaN             None  8900.024414
# 3   4      8          4  2015-09-17   1.0      1            0              0         a          a               7520.0                       10.0                    2014.0       0              NaN              NaN             None  5864.044922
# 4   5      9          4  2015-09-17   1.0      1            0              0         a          c               2030.0                        8.0                    2000.0       0              NaN              NaN             None  7325.784180

# %%
store_sales = df_results[['Store', 'Prediction']].groupby( 'Store' ).sum().reset_index()

# %%
for i in range( 0, len( store_sales ) ):
    print( 'Store {} will sell ${:,.2f} in the next 6 weeks'.format( store_sales.loc[i, 'Store'], store_sales.loc[i, 'Prediction'] ) )
# Out:
# Store 1 will sell $183,801.81 in the next 6 weeks
# Store 3 will sell $230,665.86 in the next 6 weeks
# Store 7 will sell $362,332.00 in the next 6 weeks
# Store 8 will sell $219,464.43 in the next 6 weeks
# Store 9 will sell $287,311.82 in the next 6 weeks
# Store 10 will sell $226,126.56 in the next 6 weeks
# Store 11 will sell $255,906.00 in the next 6 weeks
# Store 12 will sell $276,757.61 in the next 6 weeks
# Store 13 will sell $164,046.25 in the next 6 weeks
# Store 14 will sell $197,841.00 in the next 6 weeks
# Store 15 will sell $224,404.71 in the next 6 weeks
# Store 16 will sell $305,835.97 in the next 6 weeks
# Store 19 will sell $227,691.91 in the next 6 weeks
# Store 20 will sell $305,279.67 in the next 6 weeks
# Store 21 will sell $201,108.60 in the next 6 weeks
# Store 22 will sell $177,289.02 in the next 6 weeks
# Store 23 will sell $231,096.13 in the next 6 weeks
# Store 24 will sell $374,435.84 in the next 6 weeks
# Store 25 will sell $412,013.81 in the next 6 weeks
# Store 27 will sell $333,345.42 in the next 6 weeks
# Store 29 will sell $305,573.28 in the next 6 weeks
# Store 30 will sell $204,852.20 in the next 6 weeks
# Store 31 will sell $235,084.06 in the next 6 weeks
# Store 32 will sell $141,966.46 in the next 6 weeks
# Store 33 will sell $335,058.78 in the next 6 weeks
# Store 35 will sell $333,215.24 in the next 6 weeks
# Store 36 will sell $373,664.15 in the next 6 weeks
# Store 38 will sell $229,257.58 in the next 6 weeks
# Store 39 will sell $187,530.36 in the next 6 weeks
# Store 40 will sell $182,267.56 in the next 6 weeks
# Store 41 will sell $228,751.28 in the next 6 weeks
# Store 42 will sell $324,068.91 in the next 6 weeks
# Store 43 will sell $210,277.52 in the next 6 weeks
# Store 45 will sell $201,375.38 in the next 6 weeks
# Store 46 will sell $180,276.13 in the next 6 weeks
# Store 47 will sell $252,784.83 in the next 6 weeks
# Store 48 will sell $161,748.90 in the next 6 weeks
# Store 49 will sell $297,573.67 in the next 6 weeks
# Store 50 will sell $173,397.97 in the next 6 weeks
# Store 51 will sell $201,316.44 in the next 6 weeks
# Store 52 will sell $233,265.17 in the next 6 weeks
# Store 53 will sell $222,771.72 in the next 6 weeks
# Store 56 will sell $281,786.99 in the next 6 weeks
# Store 58 will sell $221,792.73 in the next 6 weeks
# Store 61 will sell $175,302.53 in the next 6 weeks
# Store 62 will sell $248,057.61 in the next 6 weeks
# Store 63 will sell $250,812.76 in the next 6 weeks
# Store 64 will sell $355,096.26 in the next 6 weeks
# Store 66 will sell $211,133.17 in the next 6 weeks
# Store 67 will sell $327,877.28 in the next 6 weeks
# Store 68 will sell $266,961.26 in the next 6 weeks
# Store 69 will sell $368,231.54 in the next 6 weeks
# Store 70 will sell $261,155.55 in the next 6 weeks
# Store 71 will sell $290,940.90 in the next 6 weeks
# Store 72 will sell $154,320.93 in the next 6 weeks
# Store 73 will sell $200,786.55 in the next 6 weeks
# Store 74 will sell $251,362.56 in the next 6 weeks
# Store 75 will sell $252,070.09 in the next 6 weeks
# Store 76 will sell $385,607.84 in the next 6 weeks
# Store 77 will sell $319,813.45 in the next 6 weeks
# Store 79 will sell $215,517.20 in the next 6 weeks
# Store 80 will sell $305,370.60 in the next 6 weeks
# Store 81 will sell $279,685.11 in the next 6 weeks
# Store 82 will sell $305,025.89 in the next 6 weeks
# Store 83 will sell $161,482.63 in the next 6 weeks
# Store 84 will sell $524,693.08 in the next 6 weeks
# Store 86 will sell $186,852.95 in the next 6 weeks
# Store 89 will sell $236,336.63 in the next 6 weeks
# Store 90 will sell $305,063.50 in the next 6 weeks
# Store 91 will sell $206,147.41 in the next 6 weeks
# Store 92 will sell $206,909.72 in the next 6 weeks
# Store 93 will sell $205,680.07 in the next 6 weeks
# Store 94 will sell $273,646.40 in the next 6 weeks
# Store 98 will sell $171,535.44 in the next 6 weeks
# Store 99 will sell $184,894.77 in the next 6 weeks
# Store 100 will sell $306,313.24 in the next 6 weeks
# Store 101 will sell $260,156.83 in the next 6 weeks
# Store 102 will sell $287,675.96 in the next 6 weeks
# Store 105 will sell $153,561.88 in the next 6 weeks
# Store 107 will sell $289,883.35 in the next 6 weeks
# Store 108 will sell $429,359.24 in the next 6 weeks
# Store 109 will sell $261,976.40 in the next 6 weeks
# Store 110 will sell $192,313.20 in the next 6 weeks
# Store 111 will sell $206,614.35 in the next 6 weeks
# Store 112 will sell $240,958.02 in the next 6 weeks
# Store 113 will sell $251,803.44 in the next 6 weeks
# Store 115 will sell $276,296.22 in the next 6 weeks
# Store 117 will sell $165,094.29 in the next 6 weeks
# Store 118 will sell $293,327.89 in the next 6 weeks
# Store 119 will sell $259,788.28 in the next 6 weeks
# Store 120 will sell $225,895.81 in the next 6 weeks
# Store 122 will sell $330,902.16 in the next 6 weeks
# Store 124 will sell $177,844.11 in the next 6 weeks
# Store 126 will sell $225,460.46 in the next 6 weeks
# Store 127 will sell $218,496.90 in the next 6 weeks
# Store 128 will sell $262,480.97 in the next 6 weeks
# Store 129 will sell $286,115.08 in the next 6 weeks
# Store 130 will sell $182,667.12 in the next 6 weeks
# Store 131 will sell $178,171.07 in the next 6 weeks
# Store 132 will sell $223,730.28 in the next 6 weeks
# Store 135 will sell $206,845.73 in the next 6 weeks
# Store 136 will sell $188,800.81 in the next 6 weeks
# Store 137 will sell $271,141.04 in the next 6 weeks
# Store 139 will sell $215,216.46 in the next 6 weeks
# Store 140 will sell $266,643.36 in the next 6 weeks
# Store 141 will sell $196,406.73 in the next 6 weeks
# Store 142 will sell $183,878.87 in the next 6 weeks
# Store 143 will sell $262,758.99 in the next 6 weeks
# Store 144 will sell $322,609.03 in the next 6 weeks
# Store 145 will sell $261,198.21 in the next 6 weeks
# Store 146 will sell $307,004.58 in the next 6 weeks
# Store 147 will sell $330,462.23 in the next 6 weeks
# Store 149 will sell $204,542.67 in the next 6 weeks
# Store 150 will sell $355,310.30 in the next 6 weeks
# Store 152 will sell $227,153.02 in the next 6 weeks
# Store 153 will sell $251,878.61 in the next 6 weeks
# Store 154 will sell $348,119.95 in the next 6 weeks
# Store 155 will sell $245,209.72 in the next 6 weeks
# Store 157 will sell $390,073.11 in the next 6 weeks
# Store 158 will sell $239,343.24 in the next 6 weeks
# Store 159 will sell $312,704.15 in the next 6 weeks
# Store 160 will sell $247,770.56 in the next 6 weeks
# Store 161 will sell $302,285.87 in the next 6 weeks
# Store 162 will sell $251,946.73 in the next 6 weeks
# Store 164 will sell $229,246.84 in the next 6 weeks
# Store 165 will sell $182,385.87 in the next 6 weeks
# Store 166 will sell $228,613.36 in the next 6 weeks
# Store 168 will sell $300,118.65 in the next 6 weeks
# Store 169 will sell $290,530.07 in the next 6 weeks
# Store 170 will sell $164,225.20 in the next 6 weeks
# Store 171 will sell $307,098.86 in the next 6 weeks
# Store 172 will sell $276,809.11 in the next 6 weeks
# Store 174 will sell $213,932.32 in the next 6 weeks
# Store 175 will sell $236,055.01 in the next 6 weeks
# Store 176 will sell $205,818.01 in the next 6 weeks
# Store 179 will sell $297,295.46 in the next 6 weeks
# Store 180 will sell $287,272.39 in the next 6 weeks
# Store 181 will sell $219,905.37 in the next 6 weeks
# Store 182 will sell $194,854.89 in the next 6 weeks
# Store 183 will sell $221,823.19 in the next 6 weeks
# Store 184 will sell $285,679.84 in the next 6 weeks
# Store 186 will sell $160,081.42 in the next 6 weeks
# Store 187 will sell $247,551.92 in the next 6 weeks
# Store 188 will sell $185,691.29 in the next 6 weeks
# Store 189 will sell $335,892.30 in the next 6 weeks
# Store 190 will sell $286,740.21 in the next 6 weeks
# Store 191 will sell $264,782.67 in the next 6 weeks
# Store 192 will sell $371,609.90 in the next 6 weeks
# Store 193 will sell $218,886.85 in the next 6 weeks
# Store 194 will sell $180,660.06 in the next 6 weeks
# Store 195 will sell $426,795.22 in the next 6 weeks
# Store 197 will sell $261,180.42 in the next 6 weeks
# Store 199 will sell $248,541.69 in the next 6 weeks
# Store 200 will sell $304,111.17 in the next 6 weeks
# Store 201 will sell $212,746.05 in the next 6 weeks
# Store 202 will sell $237,574.88 in the next 6 weeks
# Store 204 will sell $231,908.05 in the next 6 weeks
# Store 206 will sell $230,282.49 in the next 6 weeks
# Store 207 will sell $422,736.43 in the next 6 weeks
# Store 209 will sell $233,769.00 in the next 6 weeks
# Store 210 will sell $127,852.72 in the next 6 weeks
# Store 212 will sell $209,063.84 in the next 6 weeks
# Store 213 will sell $297,905.50 in the next 6 weeks
# Store 214 will sell $364,564.02 in the next 6 weeks
# Store 215 will sell $203,368.20 in the next 6 weeks
# Store 216 will sell $230,314.40 in the next 6 weeks
# Store 217 will sell $197,880.40 in the next 6 weeks
# Store 218 will sell $160,144.43 in the next 6 weeks
# Store 219 will sell $139,042.28 in the next 6 weeks
# Store 220 will sell $199,154.39 in the next 6 weeks
# Store 221 will sell $228,867.36 in the next 6 weeks
# Store 224 will sell $244,332.83 in the next 6 weeks
# Store 226 will sell $261,955.22 in the next 6 weeks
# Store 227 will sell $234,750.34 in the next 6 weeks
# Store 228 will sell $242,965.76 in the next 6 weeks
# Store 229 will sell $239,135.58 in the next 6 weeks
# Store 230 will sell $290,121.96 in the next 6 weeks
# Store 231 will sell $187,739.78 in the next 6 weeks
# Store 233 will sell $361,587.96 in the next 6 weeks
# Store 234 will sell $407,243.26 in the next 6 weeks
# Store 235 will sell $243,041.78 in the next 6 weeks
# Store 238 will sell $238,683.28 in the next 6 weeks
# Store 239 will sell $211,903.79 in the next 6 weeks
# Store 241 will sell $265,964.12 in the next 6 weeks
# Store 242 will sell $143,140.99 in the next 6 weeks
# Store 243 will sell $266,201.94 in the next 6 weeks
# Store 244 will sell $185,960.56 in the next 6 weeks
# Store 245 will sell $332,469.33 in the next 6 weeks
# Store 246 will sell $275,891.52 in the next 6 weeks
# Store 247 will sell $324,671.15 in the next 6 weeks
# Store 248 will sell $349,855.23 in the next 6 weeks
# Store 249 will sell $222,009.80 in the next 6 weeks
# Store 250 will sell $291,502.65 in the next 6 weeks
# Store 251 will sell $702,278.01 in the next 6 weeks
# Store 252 will sell $264,995.73 in the next 6 weeks
# Store 253 will sell $237,070.17 in the next 6 weeks
# Store 254 will sell $111,633.81 in the next 6 weeks
# Store 255 will sell $211,307.79 in the next 6 weeks
# Store 256 will sell $407,738.50 in the next 6 weeks
# Store 258 will sell $158,819.95 in the next 6 weeks
# Store 259 will sell $600,110.29 in the next 6 weeks
# Store 262 will sell $892,977.30 in the next 6 weeks
# Store 263 will sell $163,000.10 in the next 6 weeks
# Store 265 will sell $213,555.10 in the next 6 weeks
# Store 267 will sell $326,484.08 in the next 6 weeks
# Store 268 will sell $197,764.79 in the next 6 weeks
# Store 269 will sell $308,100.66 in the next 6 weeks
# Store 272 will sell $204,440.82 in the next 6 weeks
# Store 273 will sell $299,072.15 in the next 6 weeks
# Store 274 will sell $154,753.32 in the next 6 weeks
# Store 275 will sell $259,883.42 in the next 6 weeks
# Store 277 will sell $190,783.94 in the next 6 weeks
# Store 278 will sell $290,759.41 in the next 6 weeks
# Store 279 will sell $290,189.01 in the next 6 weeks
# Store 280 will sell $249,435.32 in the next 6 weeks
# Store 281 will sell $247,481.66 in the next 6 weeks
# Store 283 will sell $274,655.77 in the next 6 weeks
# Store 284 will sell $214,363.44 in the next 6 weeks
# Store 285 will sell $215,321.40 in the next 6 weeks
# Store 287 will sell $319,264.41 in the next 6 weeks
# Store 288 will sell $189,451.44 in the next 6 weeks
# Store 289 will sell $247,422.16 in the next 6 weeks
# Store 290 will sell $271,574.09 in the next 6 weeks
# Store 294 will sell $219,002.89 in the next 6 weeks
# Store 295 will sell $216,491.34 in the next 6 weeks
# Store 296 will sell $270,100.37 in the next 6 weeks
# Store 297 will sell $266,189.32 in the next 6 weeks
# Store 298 will sell $338,758.67 in the next 6 weeks
# Store 299 will sell $331,223.84 in the next 6 weeks
# Store 300 will sell $257,451.08 in the next 6 weeks
# Store 301 will sell $224,420.19 in the next 6 weeks
# Store 302 will sell $143,190.46 in the next 6 weeks
# Store 303 will sell $206,442.35 in the next 6 weeks
# Store 304 will sell $232,289.25 in the next 6 weeks
# Store 305 will sell $201,737.17 in the next 6 weeks
# Store 306 will sell $163,214.67 in the next 6 weeks
# Store 308 will sell $329,200.75 in the next 6 weeks
# Store 309 will sell $243,489.78 in the next 6 weeks
# Store 310 will sell $350,873.30 in the next 6 weeks
# Store 311 will sell $276,977.79 in the next 6 weeks
# Store 312 will sell $228,531.97 in the next 6 weeks
# Store 314 will sell $207,778.73 in the next 6 weeks
# Store 315 will sell $184,141.35 in the next 6 weeks
# Store 316 will sell $385,822.23 in the next 6 weeks
# Store 317 will sell $196,803.08 in the next 6 weeks
# Store 319 will sell $284,686.07 in the next 6 weeks
# Store 320 will sell $587,579.80 in the next 6 weeks
# Store 323 will sell $259,022.83 in the next 6 weeks
# Store 325 will sell $245,039.98 in the next 6 weeks
# Store 326 will sell $181,956.87 in the next 6 weeks
# Store 328 will sell $183,921.35 in the next 6 weeks
# Store 329 will sell $272,734.78 in the next 6 weeks
# Store 330 will sell $126,267.23 in the next 6 weeks
# Store 331 will sell $246,182.94 in the next 6 weeks
# Store 333 will sell $366,944.92 in the next 6 weeks
# Store 334 will sell $223,017.53 in the next 6 weeks
# Store 335 will sell $631,616.40 in the next 6 weeks
# Store 336 will sell $488,952.88 in the next 6 weeks
# Store 337 will sell $209,647.99 in the next 6 weeks
# Store 338 will sell $234,629.27 in the next 6 weeks
# Store 339 will sell $205,983.56 in the next 6 weeks
# Store 340 will sell $275,485.87 in the next 6 weeks
# Store 341 will sell $229,662.22 in the next 6 weeks
# Store 342 will sell $410,752.69 in the next 6 weeks
# Store 343 will sell $279,834.80 in the next 6 weeks
# Store 344 will sell $284,819.00 in the next 6 weeks
# Store 345 will sell $187,068.08 in the next 6 weeks
# Store 346 will sell $284,248.90 in the next 6 weeks
# Store 347 will sell $181,659.07 in the next 6 weeks
# Store 348 will sell $309,858.59 in the next 6 weeks
# Store 350 will sell $222,906.08 in the next 6 weeks
# Store 351 will sell $234,110.38 in the next 6 weeks
# Store 352 will sell $246,311.55 in the next 6 weeks
# Store 353 will sell $235,280.04 in the next 6 weeks
# Store 354 will sell $350,803.58 in the next 6 weeks
# Store 355 will sell $361,454.01 in the next 6 weeks
# Store 356 will sell $206,664.03 in the next 6 weeks
# Store 358 will sell $391,949.18 in the next 6 weeks
# Store 359 will sell $290,976.45 in the next 6 weeks
# Store 362 will sell $371,355.17 in the next 6 weeks
# Store 364 will sell $188,250.46 in the next 6 weeks
# Store 365 will sell $182,378.44 in the next 6 weeks
# Store 367 will sell $232,643.72 in the next 6 weeks
# Store 368 will sell $296,833.53 in the next 6 weeks
# Store 369 will sell $274,996.67 in the next 6 weeks
# Store 370 will sell $247,856.19 in the next 6 weeks
# Store 371 will sell $284,961.99 in the next 6 weeks
# Store 372 will sell $337,685.18 in the next 6 weeks
# Store 373 will sell $165,587.32 in the next 6 weeks
# Store 377 will sell $278,188.13 in the next 6 weeks
# Store 378 will sell $276,094.27 in the next 6 weeks
# Store 379 will sell $166,388.72 in the next 6 weeks
# Store 380 will sell $585,284.17 in the next 6 weeks
# Store 383 will sell $694,404.41 in the next 6 weeks
# Store 385 will sell $292,908.51 in the next 6 weeks
# Store 386 will sell $298,947.93 in the next 6 weeks
# Store 387 will sell $355,507.80 in the next 6 weeks
# Store 388 will sell $396,671.00 in the next 6 weeks
# Store 389 will sell $416,556.75 in the next 6 weeks
# Store 391 will sell $214,429.64 in the next 6 weeks
# Store 392 will sell $277,824.20 in the next 6 weeks
# Store 393 will sell $247,638.13 in the next 6 weeks
# Store 394 will sell $325,531.01 in the next 6 weeks
# Store 395 will sell $166,056.06 in the next 6 weeks
# Store 397 will sell $219,515.02 in the next 6 weeks
# Store 398 will sell $182,216.02 in the next 6 weeks
# Store 399 will sell $206,562.80 in the next 6 weeks
# Store 403 will sell $277,728.24 in the next 6 weeks
# Store 404 will sell $187,709.74 in the next 6 weeks
# Store 405 will sell $170,452.35 in the next 6 weeks
# Store 406 will sell $229,390.04 in the next 6 weeks
# Store 407 will sell $169,532.78 in the next 6 weeks
# Store 408 will sell $169,367.69 in the next 6 weeks
# Store 409 will sell $216,937.98 in the next 6 weeks
# Store 410 will sell $225,061.75 in the next 6 weeks
# Store 411 will sell $350,900.17 in the next 6 weeks
# Store 412 will sell $278,742.31 in the next 6 weeks
# Store 413 will sell $284,277.32 in the next 6 weeks
# Store 414 will sell $234,179.38 in the next 6 weeks
# Store 415 will sell $267,337.29 in the next 6 weeks
# Store 416 will sell $438,912.37 in the next 6 weeks
# Store 417 will sell $316,088.48 in the next 6 weeks
# Store 418 will sell $183,265.71 in the next 6 weeks
# Store 420 will sell $181,864.88 in the next 6 weeks
# Store 421 will sell $352,796.40 in the next 6 weeks
# Store 422 will sell $188,112.69 in the next 6 weeks
# Store 424 will sell $245,675.33 in the next 6 weeks
# Store 425 will sell $135,114.37 in the next 6 weeks
# Store 426 will sell $196,529.81 in the next 6 weeks
# Store 427 will sell $273,490.35 in the next 6 weeks
# Store 428 will sell $233,490.61 in the next 6 weeks
# Store 429 will sell $206,128.41 in the next 6 weeks
# Store 430 will sell $357,702.99 in the next 6 weeks
# Store 431 will sell $357,513.58 in the next 6 weeks
# Store 432 will sell $409,854.24 in the next 6 weeks
# Store 433 will sell $251,348.17 in the next 6 weeks
# Store 434 will sell $397,115.42 in the next 6 weeks
# Store 435 will sell $134,443.45 in the next 6 weeks
# Store 440 will sell $196,113.71 in the next 6 weeks
# Store 441 will sell $235,247.42 in the next 6 weeks
# Store 442 will sell $160,773.14 in the next 6 weeks
# Store 445 will sell $297,025.50 in the next 6 weeks
# Store 446 will sell $204,946.64 in the next 6 weeks
# Store 447 will sell $234,585.47 in the next 6 weeks
# Store 448 will sell $336,381.33 in the next 6 weeks
# Store 449 will sell $328,962.25 in the next 6 weeks
# Store 450 will sell $357,723.41 in the next 6 weeks
# Store 451 will sell $216,541.70 in the next 6 weeks
# Store 452 will sell $168,751.03 in the next 6 weeks
# Store 453 will sell $407,494.46 in the next 6 weeks
# Store 455 will sell $296,093.98 in the next 6 weeks
# Store 456 will sell $257,149.06 in the next 6 weeks
# Store 457 will sell $190,721.96 in the next 6 weeks
# Store 458 will sell $280,634.38 in the next 6 weeks
# Store 459 will sell $328,370.85 in the next 6 weeks
# Store 461 will sell $198,810.53 in the next 6 weeks
# Store 463 will sell $250,695.27 in the next 6 weeks
# Store 465 will sell $319,988.73 in the next 6 weeks
# Store 466 will sell $301,227.57 in the next 6 weeks
# Store 467 will sell $548,860.82 in the next 6 weeks
# Store 468 will sell $259,624.74 in the next 6 weeks
# Store 470 will sell $463,099.32 in the next 6 weeks
# Store 471 will sell $203,407.56 in the next 6 weeks
# Store 472 will sell $217,727.87 in the next 6 weeks
# Store 473 will sell $143,455.52 in the next 6 weeks
# Store 475 will sell $256,196.66 in the next 6 weeks
# Store 477 will sell $225,658.16 in the next 6 weeks
# Store 481 will sell $170,309.27 in the next 6 weeks
# Store 484 will sell $307,677.70 in the next 6 weeks
# Store 485 will sell $177,332.85 in the next 6 weeks
# Store 486 will sell $169,317.98 in the next 6 weeks
# Store 487 will sell $247,068.99 in the next 6 weeks
# Store 488 will sell $151,264.06 in the next 6 weeks
# Store 490 will sell $320,756.72 in the next 6 weeks
# Store 491 will sell $229,871.62 in the next 6 weeks
# Store 492 will sell $300,623.40 in the next 6 weeks
# Store 493 will sell $277,339.43 in the next 6 weeks
# Store 495 will sell $194,710.82 in the next 6 weeks
# Store 497 will sell $339,961.17 in the next 6 weeks
# Store 498 will sell $275,635.22 in the next 6 weeks
# Store 499 will sell $205,624.13 in the next 6 weeks
# Store 500 will sell $187,212.12 in the next 6 weeks
# Store 501 will sell $227,607.32 in the next 6 weeks
# Store 502 will sell $340,065.86 in the next 6 weeks
# Store 504 will sell $277,092.69 in the next 6 weeks
# Store 505 will sell $210,303.29 in the next 6 weeks
# Store 506 will sell $201,975.66 in the next 6 weeks
# Store 507 will sell $245,112.47 in the next 6 weeks
# Store 508 will sell $241,104.08 in the next 6 weeks
# Store 509 will sell $223,960.05 in the next 6 weeks
# Store 510 will sell $325,166.73 in the next 6 weeks
# Store 511 will sell $234,514.10 in the next 6 weeks
# Store 512 will sell $266,555.66 in the next 6 weeks
# Store 514 will sell $226,459.35 in the next 6 weeks
# Store 515 will sell $251,388.67 in the next 6 weeks
# Store 516 will sell $202,892.33 in the next 6 weeks
# Store 517 will sell $238,413.12 in the next 6 weeks
# Store 518 will sell $190,654.24 in the next 6 weeks
# Store 519 will sell $199,757.98 in the next 6 weeks
# Store 520 will sell $158,573.27 in the next 6 weeks
# Store 521 will sell $180,978.57 in the next 6 weeks
# Store 522 will sell $247,825.18 in the next 6 weeks
# Store 524 will sell $380,506.99 in the next 6 weeks
# Store 527 will sell $417,785.92 in the next 6 weeks
# Store 528 will sell $278,013.65 in the next 6 weeks
# Store 529 will sell $330,749.46 in the next 6 weeks
# Store 530 will sell $258,105.36 in the next 6 weeks
# Store 531 will sell $230,478.34 in the next 6 weeks
# Store 532 will sell $427,403.53 in the next 6 weeks
# Store 533 will sell $371,449.14 in the next 6 weeks
# Store 534 will sell $271,360.04 in the next 6 weeks
# Store 535 will sell $309,986.41 in the next 6 weeks
# Store 536 will sell $321,872.08 in the next 6 weeks
# Store 537 will sell $204,939.81 in the next 6 weeks
# Store 538 will sell $162,968.27 in the next 6 weeks
# Store 539 will sell $443,916.56 in the next 6 weeks
# Store 540 will sell $220,601.21 in the next 6 weeks
# Store 541 will sell $267,516.77 in the next 6 weeks
# Store 542 will sell $231,964.62 in the next 6 weeks
# Store 543 will sell $114,005.86 in the next 6 weeks
# Store 545 will sell $397,207.07 in the next 6 weeks
# Store 547 will sell $164,470.08 in the next 6 weeks
# Store 548 will sell $210,362.52 in the next 6 weeks
# Store 549 will sell $201,957.63 in the next 6 weeks
# Store 550 will sell $205,161.83 in the next 6 weeks
# Store 551 will sell $256,159.13 in the next 6 weeks
# Store 552 will sell $249,088.54 in the next 6 weeks
# Store 553 will sell $280,800.11 in the next 6 weeks
# Store 554 will sell $225,691.87 in the next 6 weeks
# Store 555 will sell $175,124.80 in the next 6 weeks
# Store 557 will sell $176,763.54 in the next 6 weeks
# Store 558 will sell $129,543.47 in the next 6 weeks
# Store 561 will sell $284,405.19 in the next 6 weeks
# Store 562 will sell $861,804.05 in the next 6 weeks
# Store 563 will sell $207,721.54 in the next 6 weeks
# Store 564 will sell $209,718.92 in the next 6 weeks
# Store 565 will sell $253,578.20 in the next 6 weeks
# Store 566 will sell $185,880.06 in the next 6 weeks
# Store 567 will sell $187,254.62 in the next 6 weeks
# Store 568 will sell $189,481.19 in the next 6 weeks
# Store 570 will sell $170,284.91 in the next 6 weeks
# Store 571 will sell $308,710.85 in the next 6 weeks
# Store 572 will sell $201,151.75 in the next 6 weeks
# Store 573 will sell $163,191.88 in the next 6 weeks
# Store 574 will sell $346,519.25 in the next 6 weeks
# Store 575 will sell $199,321.46 in the next 6 weeks
# Store 577 will sell $188,194.72 in the next 6 weeks
# Store 578 will sell $372,781.41 in the next 6 weeks
# Store 579 will sell $335,100.98 in the next 6 weeks
# Store 580 will sell $395,348.22 in the next 6 weeks
# Store 581 will sell $204,537.49 in the next 6 weeks
# Store 582 will sell $259,301.02 in the next 6 weeks
# Store 584 will sell $182,218.12 in the next 6 weeks
# Store 585 will sell $204,592.61 in the next 6 weeks
# Store 586 will sell $576,488.73 in the next 6 weeks
# Store 587 will sell $317,643.11 in the next 6 weeks
# Store 588 will sell $253,366.08 in the next 6 weeks
# Store 589 will sell $149,924.62 in the next 6 weeks
# Store 590 will sell $199,525.19 in the next 6 weeks
# Store 591 will sell $207,889.88 in the next 6 weeks
# Store 592 will sell $179,719.39 in the next 6 weeks
# Store 593 will sell $388,849.52 in the next 6 weeks
# Store 597 will sell $201,273.48 in the next 6 weeks
# Store 598 will sell $242,366.92 in the next 6 weeks
# Store 600 will sell $197,264.37 in the next 6 weeks
# Store 601 will sell $175,547.27 in the next 6 weeks
# Store 602 will sell $230,850.51 in the next 6 weeks
# Store 603 will sell $243,955.91 in the next 6 weeks
# Store 604 will sell $297,389.62 in the next 6 weeks
# Store 605 will sell $214,018.92 in the next 6 weeks
# Store 610 will sell $181,681.86 in the next 6 weeks
# Store 611 will sell $244,383.86 in the next 6 weeks
# Store 612 will sell $212,618.95 in the next 6 weeks
# Store 615 will sell $369,567.63 in the next 6 weeks
# Store 616 will sell $278,268.52 in the next 6 weeks
# Store 618 will sell $279,912.43 in the next 6 weeks
# Store 619 will sell $159,386.29 in the next 6 weeks
# Store 620 will sell $287,364.63 in the next 6 weeks
# Store 621 will sell $219,666.44 in the next 6 weeks
# Store 622 will sell $125,864.76 in the next 6 weeks
# Store 623 will sell $242,625.07 in the next 6 weeks
# Store 624 will sell $287,644.00 in the next 6 weeks
# Store 625 will sell $225,648.54 in the next 6 weeks
# Store 627 will sell $252,510.83 in the next 6 weeks
# Store 628 will sell $261,302.57 in the next 6 weeks
# Store 629 will sell $285,380.18 in the next 6 weeks
# Store 631 will sell $196,048.39 in the next 6 weeks
# Store 632 will sell $261,858.08 in the next 6 weeks
# Store 633 will sell $225,295.67 in the next 6 weeks
# Store 636 will sell $214,886.00 in the next 6 weeks
# Store 637 will sell $221,412.01 in the next 6 weeks
# Store 638 will sell $241,271.59 in the next 6 weeks
# Store 639 will sell $202,911.36 in the next 6 weeks
# Store 640 will sell $434,456.52 in the next 6 weeks
# Store 641 will sell $233,319.85 in the next 6 weeks
# Store 642 will sell $150,120.05 in the next 6 weeks
# Store 643 will sell $280,673.68 in the next 6 weeks
# Store 644 will sell $292,220.44 in the next 6 weeks
# Store 645 will sell $372,025.14 in the next 6 weeks
# Store 646 will sell $194,451.88 in the next 6 weeks
# Store 647 will sell $253,774.26 in the next 6 weeks
# Store 650 will sell $249,815.58 in the next 6 weeks
# Store 651 will sell $272,226.90 in the next 6 weeks
# Store 653 will sell $183,213.99 in the next 6 weeks
# Store 655 will sell $272,044.22 in the next 6 weeks
# Store 656 will sell $125,845.30 in the next 6 weeks
# Store 657 will sell $257,636.07 in the next 6 weeks
# Store 658 will sell $205,348.30 in the next 6 weeks
# Store 659 will sell $223,450.45 in the next 6 weeks
# Store 660 will sell $194,572.22 in the next 6 weeks
# Store 661 will sell $273,177.37 in the next 6 weeks
# Store 662 will sell $330,234.98 in the next 6 weeks
# Store 663 will sell $229,710.29 in the next 6 weeks
# Store 665 will sell $262,730.18 in the next 6 weeks
# Store 666 will sell $244,527.53 in the next 6 weeks
# Store 667 will sell $349,718.50 in the next 6 weeks
# Store 669 will sell $185,410.88 in the next 6 weeks
# Store 670 will sell $206,670.72 in the next 6 weeks
# Store 671 will sell $208,507.13 in the next 6 weeks
# Store 673 will sell $257,415.09 in the next 6 weeks
# Store 674 will sell $316,314.12 in the next 6 weeks
# Store 675 will sell $156,404.82 in the next 6 weeks
# Store 676 will sell $437,011.27 in the next 6 weeks
# Store 677 will sell $271,472.01 in the next 6 weeks
# Store 678 will sell $252,579.17 in the next 6 weeks
# Store 680 will sell $188,899.48 in the next 6 weeks
# Store 681 will sell $158,127.70 in the next 6 weeks
# Store 684 will sell $246,006.61 in the next 6 weeks
# Store 685 will sell $223,331.20 in the next 6 weeks
# Store 687 will sell $342,425.09 in the next 6 weeks
# Store 689 will sell $282,647.25 in the next 6 weeks
# Store 690 will sell $223,968.18 in the next 6 weeks
# Store 691 will sell $271,586.05 in the next 6 weeks
# Store 692 will sell $246,805.18 in the next 6 weeks
# Store 693 will sell $229,429.47 in the next 6 weeks
# Store 694 will sell $310,704.24 in the next 6 weeks
# Store 695 will sell $196,634.17 in the next 6 weeks
# Store 696 will sell $329,036.10 in the next 6 weeks
# Store 697 will sell $380,933.12 in the next 6 weeks
# Store 699 will sell $336,173.58 in the next 6 weeks
# Store 700 will sell $165,806.39 in the next 6 weeks
# Store 701 will sell $174,533.57 in the next 6 weeks
# Store 702 will sell $146,885.01 in the next 6 weeks
# Store 703 will sell $113,824.85 in the next 6 weeks
# Store 705 will sell $306,319.02 in the next 6 weeks
# Store 706 will sell $230,734.41 in the next 6 weeks
# Store 707 will sell $336,052.43 in the next 6 weeks
# Store 710 will sell $176,779.06 in the next 6 weeks
# Store 711 will sell $202,146.59 in the next 6 weeks
# Store 712 will sell $229,388.19 in the next 6 weeks
# Store 713 will sell $443,083.75 in the next 6 weeks
# Store 714 will sell $174,921.65 in the next 6 weeks
# Store 716 will sell $191,571.70 in the next 6 weeks
# Store 717 will sell $212,022.22 in the next 6 weeks
# Store 718 will sell $269,011.51 in the next 6 weeks
# Store 719 will sell $170,045.71 in the next 6 weeks
# Store 720 will sell $259,239.79 in the next 6 weeks
# Store 721 will sell $275,343.75 in the next 6 weeks
# Store 722 will sell $358,357.72 in the next 6 weeks
# Store 723 will sell $250,820.39 in the next 6 weeks
# Store 724 will sell $284,126.16 in the next 6 weeks
# Store 725 will sell $245,366.69 in the next 6 weeks
# Store 727 will sell $180,655.32 in the next 6 weeks
# Store 728 will sell $168,513.34 in the next 6 weeks
# Store 729 will sell $416,609.56 in the next 6 weeks
# Store 731 will sell $354,795.09 in the next 6 weeks
# Store 732 will sell $308,170.81 in the next 6 weeks
# Store 733 will sell $677,484.75 in the next 6 weeks
# Store 734 will sell $236,751.46 in the next 6 weeks
# Store 736 will sell $179,097.48 in the next 6 weeks
# Store 737 will sell $231,530.88 in the next 6 weeks
# Store 738 will sell $327,172.46 in the next 6 weeks
# Store 739 will sell $323,950.39 in the next 6 weeks
# Store 740 will sell $273,036.76 in the next 6 weeks
# Store 741 will sell $290,590.82 in the next 6 weeks
# Store 742 will sell $323,687.39 in the next 6 weeks
# Store 744 will sell $298,515.63 in the next 6 weeks
# Store 746 will sell $209,973.11 in the next 6 weeks
# Store 748 will sell $198,217.25 in the next 6 weeks
# Store 749 will sell $208,717.76 in the next 6 weeks
# Store 750 will sell $171,703.05 in the next 6 weeks
# Store 751 will sell $176,254.86 in the next 6 weeks
# Store 752 will sell $201,358.82 in the next 6 weeks
# Store 753 will sell $273,341.81 in the next 6 weeks
# Store 756 will sell $555,468.19 in the next 6 weeks
# Store 757 will sell $260,851.20 in the next 6 weeks
# Store 758 will sell $206,211.30 in the next 6 weeks
# Store 759 will sell $278,205.05 in the next 6 weeks
# Store 762 will sell $154,655.25 in the next 6 weeks
# Store 763 will sell $269,609.23 in the next 6 weeks
# Store 764 will sell $138,990.87 in the next 6 weeks
# Store 765 will sell $242,796.32 in the next 6 weeks
# Store 766 will sell $239,519.88 in the next 6 weeks
# Store 767 will sell $248,589.43 in the next 6 weeks
# Store 768 will sell $495,622.41 in the next 6 weeks
# Store 769 will sell $429,770.54 in the next 6 weeks
# Store 770 will sell $225,055.96 in the next 6 weeks
# Store 771 will sell $265,706.85 in the next 6 weeks
# Store 772 will sell $153,225.35 in the next 6 weeks
# Store 773 will sell $216,241.02 in the next 6 weeks
# Store 774 will sell $224,875.72 in the next 6 weeks
# Store 775 will sell $265,181.28 in the next 6 weeks
# Store 776 will sell $171,804.83 in the next 6 weeks
# Store 777 will sell $158,834.81 in the next 6 weeks
# Store 778 will sell $235,359.84 in the next 6 weeks
# Store 782 will sell $198,792.25 in the next 6 weeks
# Store 784 will sell $290,571.38 in the next 6 weeks
# Store 785 will sell $243,338.10 in the next 6 weeks
# Store 789 will sell $150,708.42 in the next 6 weeks
# Store 790 will sell $316,399.36 in the next 6 weeks
# Store 791 will sell $289,529.99 in the next 6 weeks
# Store 792 will sell $209,689.10 in the next 6 weeks
# Store 793 will sell $190,499.97 in the next 6 weeks
# Store 795 will sell $152,293.84 in the next 6 weeks
# Store 796 will sell $288,158.68 in the next 6 weeks
# Store 797 will sell $177,906.08 in the next 6 weeks
# Store 799 will sell $373,822.70 in the next 6 weeks
# Store 800 will sell $199,174.41 in the next 6 weeks
# Store 801 will sell $208,445.21 in the next 6 weeks
# Store 802 will sell $216,211.08 in the next 6 weeks
# Store 803 will sell $240,408.10 in the next 6 weeks
# Store 804 will sell $172,301.04 in the next 6 weeks
# Store 805 will sell $241,004.69 in the next 6 weeks
# Store 806 will sell $213,894.86 in the next 6 weeks
# Store 807 will sell $383,381.44 in the next 6 weeks
# Store 809 will sell $372,952.85 in the next 6 weeks
# Store 810 will sell $242,980.84 in the next 6 weeks
# Store 811 will sell $166,164.26 in the next 6 weeks
# Store 813 will sell $229,287.02 in the next 6 weeks
# Store 815 will sell $251,544.83 in the next 6 weeks
# Store 816 will sell $199,478.99 in the next 6 weeks
# Store 818 will sell $189,983.37 in the next 6 weeks
# Store 819 will sell $249,989.07 in the next 6 weeks
# Store 820 will sell $414,392.20 in the next 6 weeks
# Store 822 will sell $248,334.43 in the next 6 weeks
# Store 823 will sell $255,140.66 in the next 6 weeks
# Store 824 will sell $268,393.54 in the next 6 weeks
# Store 825 will sell $197,078.95 in the next 6 weeks
# Store 826 will sell $365,956.92 in the next 6 weeks
# Store 829 will sell $223,375.05 in the next 6 weeks
# Store 831 will sell $440,102.83 in the next 6 weeks
# Store 832 will sell $190,718.98 in the next 6 weeks
# Store 833 will sell $183,450.08 in the next 6 weeks
# Store 835 will sell $219,456.82 in the next 6 weeks
# Store 837 will sell $139,786.00 in the next 6 weeks
# Store 840 will sell $281,041.74 in the next 6 weeks
# Store 842 will sell $646,590.14 in the next 6 weeks
# Store 844 will sell $156,655.19 in the next 6 weeks
# Store 845 will sell $173,146.38 in the next 6 weeks
# Store 846 will sell $274,993.79 in the next 6 weeks
# Store 847 will sell $273,031.27 in the next 6 weeks
# Store 848 will sell $184,954.99 in the next 6 weeks
# Store 849 will sell $299,813.97 in the next 6 weeks
# Store 850 will sell $236,398.07 in the next 6 weeks
# Store 851 will sell $216,823.18 in the next 6 weeks
# Store 852 will sell $168,028.08 in the next 6 weeks
# Store 853 will sell $352,554.85 in the next 6 weeks
# Store 855 will sell $189,695.67 in the next 6 weeks
# Store 856 will sell $277,812.44 in the next 6 weeks
# Store 857 will sell $303,919.57 in the next 6 weeks
# Store 858 will sell $193,033.00 in the next 6 weeks
# Store 859 will sell $270,226.24 in the next 6 weeks
# Store 860 will sell $244,518.62 in the next 6 weeks
# Store 861 will sell $127,693.14 in the next 6 weeks
# Store 862 will sell $280,677.74 in the next 6 weeks
# Store 863 will sell $352,630.40 in the next 6 weeks
# Store 864 will sell $174,822.56 in the next 6 weeks
# Store 865 will sell $307,752.41 in the next 6 weeks
# Store 866 will sell $250,237.13 in the next 6 weeks
# Store 867 will sell $214,040.77 in the next 6 weeks
# Store 868 will sell $379,902.24 in the next 6 weeks
# Store 871 will sell $262,228.41 in the next 6 weeks
# Store 872 will sell $333,758.15 in the next 6 weeks
# Store 874 will sell $200,383.63 in the next 6 weeks
# Store 875 will sell $205,445.31 in the next 6 weeks
# Store 877 will sell $252,106.78 in the next 6 weeks
# Store 879 will sell $115,341.68 in the next 6 weeks
# Store 880 will sell $311,655.05 in the next 6 weeks
# Store 881 will sell $168,836.66 in the next 6 weeks
# Store 882 will sell $238,391.02 in the next 6 weeks
# Store 883 will sell $188,778.81 in the next 6 weeks
# Store 884 will sell $246,781.89 in the next 6 weeks
# Store 885 will sell $236,889.86 in the next 6 weeks
# Store 886 will sell $265,797.89 in the next 6 weeks
# Store 887 will sell $203,714.95 in the next 6 weeks
# Store 888 will sell $301,338.52 in the next 6 weeks
# Store 890 will sell $208,056.56 in the next 6 weeks
# Store 891 will sell $321,316.85 in the next 6 weeks
# Store 893 will sell $256,571.67 in the next 6 weeks
# Store 894 will sell $300,148.05 in the next 6 weeks
# Store 895 will sell $380,891.37 in the next 6 weeks
# Store 896 will sell $287,402.93 in the next 6 weeks
# Store 897 will sell $133,638.09 in the next 6 weeks
# Store 900 will sell $246,439.10 in the next 6 weeks
# Store 901 will sell $276,271.15 in the next 6 weeks
# Store 902 will sell $173,425.38 in the next 6 weeks
# Store 903 will sell $399,682.61 in the next 6 weeks
# Store 904 will sell $209,412.44 in the next 6 weeks
# Store 905 will sell $279,375.13 in the next 6 weeks
# Store 906 will sell $391,528.92 in the next 6 weeks
# Store 907 will sell $274,475.38 in the next 6 weeks
# Store 908 will sell $157,707.62 in the next 6 weeks
# Store 909 will sell $308,494.19 in the next 6 weeks
# Store 911 will sell $395,250.44 in the next 6 weeks
# Store 912 will sell $249,207.35 in the next 6 weeks
# Store 913 will sell $318,156.64 in the next 6 weeks
# Store 914 will sell $312,947.25 in the next 6 weeks
# Store 915 will sell $250,375.98 in the next 6 weeks
# Store 916 will sell $220,458.78 in the next 6 weeks
# Store 917 will sell $260,895.08 in the next 6 weeks
# Store 919 will sell $204,604.84 in the next 6 weeks
# Store 920 will sell $234,948.87 in the next 6 weeks
# Store 922 will sell $292,031.25 in the next 6 weeks
# Store 924 will sell $176,145.83 in the next 6 weeks
# Store 925 will sell $227,070.21 in the next 6 weeks
# Store 926 will sell $203,128.69 in the next 6 weeks
# Store 927 will sell $254,949.17 in the next 6 weeks
# Store 928 will sell $316,935.52 in the next 6 weeks
# Store 929 will sell $250,275.84 in the next 6 weeks
# Store 930 will sell $269,747.84 in the next 6 weeks
# Store 931 will sell $150,222.72 in the next 6 weeks
# Store 932 will sell $249,704.23 in the next 6 weeks
# Store 934 will sell $205,248.04 in the next 6 weeks
# Store 935 will sell $240,307.61 in the next 6 weeks
# Store 936 will sell $269,306.31 in the next 6 weeks
# Store 937 will sell $310,277.75 in the next 6 weeks
# Store 938 will sell $363,438.71 in the next 6 weeks
# Store 939 will sell $249,774.38 in the next 6 weeks
# Store 941 will sell $202,784.22 in the next 6 weeks
# Store 942 will sell $205,980.61 in the next 6 weeks
# Store 943 will sell $266,575.70 in the next 6 weeks
# Store 944 will sell $255,881.91 in the next 6 weeks
# Store 945 will sell $193,577.21 in the next 6 weeks
# Store 946 will sell $180,349.89 in the next 6 weeks
# Store 947 will sell $265,790.70 in the next 6 weeks
# Store 948 will sell $371,534.11 in the next 6 weeks
# Store 950 will sell $221,160.54 in the next 6 weeks
# Store 951 will sell $249,850.43 in the next 6 weeks
# Store 952 will sell $257,048.24 in the next 6 weeks
# Store 954 will sell $271,739.79 in the next 6 weeks
# Store 955 will sell $189,137.82 in the next 6 weeks
# Store 956 will sell $138,310.17 in the next 6 weeks
# Store 960 will sell $201,332.72 in the next 6 weeks
# Store 961 will sell $275,777.78 in the next 6 weeks
# Store 962 will sell $241,933.17 in the next 6 weeks
# Store 964 will sell $364,951.87 in the next 6 weeks
# Store 965 will sell $335,950.08 in the next 6 weeks
# Store 966 will sell $200,320.48 in the next 6 weeks
# Store 967 will sell $343,306.69 in the next 6 weeks
# Store 969 will sell $141,873.62 in the next 6 weeks
# Store 970 will sell $123,827.31 in the next 6 weeks
# Store 973 will sell $227,821.05 in the next 6 weeks
# Store 974 will sell $461,115.31 in the next 6 weeks
# Store 975 will sell $214,453.81 in the next 6 weeks
# Store 976 will sell $278,952.94 in the next 6 weeks
# Store 977 will sell $189,768.18 in the next 6 weeks
# Store 980 will sell $287,731.08 in the next 6 weeks
# Store 983 will sell $382,579.09 in the next 6 weeks
# Store 984 will sell $236,121.35 in the next 6 weeks
# Store 985 will sell $246,899.84 in the next 6 weeks
# Store 986 will sell $234,506.43 in the next 6 weeks
# Store 988 will sell $180,934.55 in the next 6 weeks
# Store 989 will sell $190,391.74 in the next 6 weeks
# Store 991 will sell $232,892.36 in the next 6 weeks
# Store 992 will sell $221,260.55 in the next 6 weeks
# Store 994 will sell $172,010.65 in the next 6 weeks
# Store 997 will sell $174,713.12 in the next 6 weeks
# Store 998 will sell $183,083.16 in the next 6 weeks
# Store 1000 will sell $297,750.54 in the next 6 weeks
# Store 1003 will sell $280,373.72 in the next 6 weeks
# Store 1004 will sell $172,804.66 in the next 6 weeks
# Store 1005 will sell $248,669.44 in the next 6 weeks
# Store 1007 will sell $278,157.13 in the next 6 weeks
# Store 1008 will sell $220,304.37 in the next 6 weeks
# Store 1009 will sell $197,938.52 in the next 6 weeks
# Store 1010 will sell $286,633.19 in the next 6 weeks
# Store 1011 will sell $276,121.99 in the next 6 weeks
# Store 1012 will sell $212,518.04 in the next 6 weeks
# Store 1013 will sell $139,435.16 in the next 6 weeks
# Store 1014 will sell $474,230.82 in the next 6 weeks
# Store 1015 will sell $177,346.08 in the next 6 weeks
# Store 1016 will sell $178,856.90 in the next 6 weeks
# Store 1019 will sell $296,498.27 in the next 6 weeks
# Store 1020 will sell $326,096.71 in the next 6 weeks
# Store 1022 will sell $293,987.35 in the next 6 weeks
# Store 1024 will sell $255,735.58 in the next 6 weeks
# Store 1025 will sell $281,473.16 in the next 6 weeks
# Store 1026 will sell $340,237.65 in the next 6 weeks
# Store 1027 will sell $502,400.46 in the next 6 weeks
# Store 1028 will sell $193,886.39 in the next 6 weeks
# Store 1031 will sell $186,803.38 in the next 6 weeks
# Store 1036 will sell $205,058.00 in the next 6 weeks
# Store 1037 will sell $268,895.53 in the next 6 weeks
# Store 1038 will sell $237,693.21 in the next 6 weeks
# Store 1039 will sell $249,265.62 in the next 6 weeks
# Store 1040 will sell $335,639.57 in the next 6 weeks
# Store 1041 will sell $251,771.25 in the next 6 weeks
# Store 1042 will sell $171,489.18 in the next 6 weeks
# Store 1044 will sell $219,857.86 in the next 6 weeks
# Store 1045 will sell $357,315.70 in the next 6 weeks
# Store 1047 will sell $185,948.46 in the next 6 weeks
# Store 1048 will sell $233,489.47 in the next 6 weeks
# Store 1049 will sell $124,508.05 in the next 6 weeks
# Store 1050 will sell $222,948.52 in the next 6 weeks
# Store 1051 will sell $266,934.88 in the next 6 weeks
# Store 1052 will sell $267,558.80 in the next 6 weeks
# Store 1053 will sell $296,389.94 in the next 6 weeks
# Store 1054 will sell $244,289.43 in the next 6 weeks
# Store 1056 will sell $138,464.87 in the next 6 weeks
# Store 1057 will sell $259,451.45 in the next 6 weeks
# Store 1058 will sell $268,593.20 in the next 6 weeks
# Store 1059 will sell $337,538.46 in the next 6 weeks
# Store 1060 will sell $282,895.35 in the next 6 weeks
# Store 1061 will sell $302,283.24 in the next 6 weeks
# Store 1062 will sell $246,645.71 in the next 6 weeks
# Store 1063 will sell $179,139.38 in the next 6 weeks
# Store 1064 will sell $385,278.45 in the next 6 weeks
# Store 1065 will sell $159,795.98 in the next 6 weeks
# Store 1066 will sell $430,996.21 in the next 6 weeks
# Store 1067 will sell $241,782.34 in the next 6 weeks
# Store 1068 will sell $177,420.77 in the next 6 weeks
# Store 1070 will sell $280,826.20 in the next 6 weeks
# Store 1071 will sell $233,208.22 in the next 6 weeks
# Store 1072 will sell $205,207.35 in the next 6 weeks
# Store 1073 will sell $268,327.87 in the next 6 weeks
# Store 1076 will sell $154,703.06 in the next 6 weeks
# Store 1077 will sell $171,962.78 in the next 6 weeks
# Store 1078 will sell $238,628.78 in the next 6 weeks
# Store 1079 will sell $279,986.21 in the next 6 weeks
# Store 1080 will sell $392,224.42 in the next 6 weeks
# Store 1083 will sell $196,330.64 in the next 6 weeks
# Store 1084 will sell $251,396.11 in the next 6 weeks
# Store 1086 will sell $256,584.51 in the next 6 weeks
# Store 1087 will sell $256,636.17 in the next 6 weeks
# Store 1088 will sell $200,254.33 in the next 6 weeks
# Store 1089 will sell $393,805.94 in the next 6 weeks
# Store 1091 will sell $343,202.90 in the next 6 weeks
# Store 1092 will sell $481,724.81 in the next 6 weeks
# Store 1094 will sell $187,165.49 in the next 6 weeks
# Store 1096 will sell $254,762.88 in the next 6 weeks
# Store 1097 will sell $442,640.23 in the next 6 weeks
# Store 1099 will sell $357,675.82 in the next 6 weeks
# Store 1100 will sell $197,079.40 in the next 6 weeks
# Store 1101 will sell $383,649.59 in the next 6 weeks
# Store 1102 will sell $276,310.71 in the next 6 weeks
# Store 1103 will sell $175,943.85 in the next 6 weeks
# Store 1104 will sell $184,791.26 in the next 6 weeks
# Store 1105 will sell $168,326.22 in the next 6 weeks
# Store 1106 will sell $189,122.07 in the next 6 weeks
# Store 1107 will sell $245,675.62 in the next 6 weeks
# Store 1109 will sell $178,803.48 in the next 6 weeks
# Store 1111 will sell $210,322.16 in the next 6 weeks
# Store 1112 will sell $354,634.84 in the next 6 weeks
# Store 1113 will sell $272,188.36 in the next 6 weeks
# Store 1114 will sell $896,521.17 in the next 6 weeks
# Store 1115 will sell $184,850.57 in the next 6 weeks

# %% [markdown]
# # 20. REFERENCES
# ---

# %% [markdown]
# ## 20.0. Rossmann Store Competition

# %% [markdown]
# 1. https://www.kaggle.com/hely333/eda-regression
# 2. http://rstudio-pubs-static.s3.amazonaws.com/142772_218508e3f94e4419944e9104505b6f17.html
# 3. http://blog.kaggle.com/2016/01/22/rossmann-store-sales-winners-interview-3rd-place-cheng-gui/
# 4. https://www.kaggle.com/c/rossmann-store-sales/discussion/17974
# 5. https://jikeme.com/rossmann-store-sales-winners-interview-3rd-place-neokami-inc
# 6. https://github.com/li-kai/rossman-store-sales/blob/master/hw3-rossman.ipynb
# 7. http://blog.kaggle.com/2015/12/21/rossmann-store-sales-winners-interview-1st-place-gert/
# 8. http://cs229.stanford.edu/proj2015/218_report.pdf
# 9. http://rohanrao91.blogspot.com/2015/12/rossmann-store-sales.html
# 10. https://mabrek.github.io/blog/kaggle-forecasting/
# 11. https://arxiv.org/pdf/1604.06737.pdf
# 12. http://www.johnatate.com/learning-from-the-best-rossman-sales-kaggle-winners.html
# 13. https://www.kaggle.com/abhilashawasthi/xgb-rossmann
# 14. https://www.kaggle.com/c/rossmann-store-sales/discussion/18024
# 15. https://rpubs.com/gpetho/142772
# 16. http://www.3leafnodes.com/random-forest-regression-train-with-one-feature-grid-search
# 17. https://github.com/Semantive/Kaggle-Demand-Forecasting-Models

# %% [markdown]
# ## 20.1. Encoding Cyclical Values

# %% [markdown]
# 1. https://www.avanwyk.com/encoding-cyclical-features-for-deep-learning/
# 2. https://ianlondon.github.io/blog/encoding-cyclical-features-24hour-time/
# 3. https://www.kaggle.com/avanwyk/encoding-cyclical-features-for-deep-learning
# 4. http://blog.davidkaleko.com/feature-engineering-cyclical-features.html

# %% [markdown]
# ## 20.2. XGBoost Fine Tunning

# %% [markdown]
# 1. https://stackoverflow.com/questions/37583263/scikit-learn-cross-validation-custom-splits-for-time-series-data
# 2. https://datascience-enthusiast.com/R/ML_python_R_part2.html
# 3. https://www.kaggle.com/tilii7/hyperparameter-grid-search-with-xgboost
# 4. https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/
# 5. https://blog.cambridgespark.com/hyperparameter-tuning-in-xgboost-4ff9100a3b2f
# 6. https://www.kaggle.com/general/17120
# 7. https://www.kaggle.com/stuarthallows/using-xgboost-with-scikit-learn
# 8. https://www.kaggle.com/pablocastilla/predict-house-prices-with-xgboost-regression
#
# 1. http://krasserm.github.io/2018/03/21/bayesian-optimization/

# %% [markdown]
# ## 20.3. Bayesian Optimization

# %% [markdown]
# 1. http://krasserm.github.io/2018/03/21/bayesian-optimization/

# %% [markdown]
# ## 20.4. Public Dataset

# %% [markdown]
# 1. https://www.kaggle.com/marcinex1423/salesdb-grocery#salesDB_grocery_market.zip
# 1. https://www.kaggle.com/fayomi/advertising
# 2. https://www.kaggle.com/harlfoxem/housesalesprediction
# 3. https://github.com/awesomedata/awesome-public-datasets
# 4. https://www.kdnuggets.com/datasets/index.html
# 5. https://www.kaggle.com/devashish0507/big-mart-sales-prediction
# 6. https://archive.ics.uci.edu/ml/datasets/Statlog+(Vehicle+Silhouettes)

# %% [markdown]
# ## 20.5. Time Series Courses

# %% [markdown]
# 1. https://www.kaggle.com/kashnitsky/topic-9-part-1-time-series-analysis-in-python
# 2. https://www.kaggle.com/devilears/siraj-s-steps-lstm
# 3.

# %% [markdown]
# ## 20.6. Feature Selection

# %% [markdown]
# 1. http://dkopczyk.quantee.co.uk/feature-selection/
# 2. https://towardsdatascience.com/the-hitchhikers-guide-to-feature-extraction-b4c157e96631

# %% [markdown]
# ## 20.7. Data Exploration

# %% [markdown]
# 1. https://www.kaggle.com/breemen/nyc-taxi-fare-data-exploration

# %% [markdown]
# ## 20.8. Prediction Interval

# %% [markdown]
# 1. https://blog.datadive.net/prediction-intervals-for-random-forests/
# 2. https://stats.stackexchange.com/questions/16493/difference-between-confidence-intervals-and-prediction-intervals/16496#16496
# 3. https://towardsdatascience.com/regression-prediction-intervals-with-xgboost-428e0a018b

# %% [markdown]
# ## 20.9. Cross Validation Folds by Index

# %%
# define dates to nested cross-validation
training_start = datetime( 2013, 1, 1 )
training_end = datetime( 2015, 1, 13 )
holdout_end = datetime( 2015, 6, 13 )

# number of folds
kfold = 10

# how many days between training end and holdout end
n_day = np.round( ( holdout_end - training_end ).days / kfold )

# K fold cross validation
cv_folder = []
for i in range( 1, kfold + 1 ):
    # training
    fold_training_start = training_start
    fold_training_end = training_end + timedelta( days=( i - 1 )*n_day )

    # valid
    fold_valid_start = fold_training_end
    fold_valid_end = fold_valid_start + timedelta( days=( n_day ) )
    
    # model training with k fold
    x_train = X_train[(X_train['date'] >= fold_training_start) & (X_train['date'] <= fold_training_end)]
    
    if i == kfold:
        x_valid = X_train[(X_train['date'] > fold_valid_start) & (X_train['date'] <= holdout_end)]
    else:
        x_valid = X_train[(X_train['date'] > fold_valid_start) & (X_train['date'] <= fold_valid_end)]
    
    # get the index of the training and valid into a list
    train_list = x_train.index.values.tolist()
    valid_list = x_valid.index.values.tolist()
    
    print( i )
    print( 'min train date:{} index:{}'.format( np.min( x_train['date'] ) , np.min( x_train.index.values ) ) ) 
    print( 'max train date:{} index:{}'.format( np.max( x_train['date'] ) , np.max( x_train.index.values ) ) ) 
    
    print( 'min valid date:{} index:{}'.format( np.min( x_valid['date'] ) , np.min( x_valid.index.values ) ) ) 
    print( 'max valid date:{} index:{}'.format( np.max( x_valid['date'] ) , np.max( x_valid.index.values ) ) ) 
    
    aux = (valid_list, valid_list)
    cv_folder.append( aux )

    if i > 1:
        cv_results = xgb.cv( params, dtrain, num_boost_round=999, seed=42, nfold=len(cv_folder), folds=cv_folder, metrics={'mae'}, early_stopping_rounds=10 )
